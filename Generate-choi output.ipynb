# %%
from preprocessing.EntityNameRetriever import EntityNameRetriever
from preprocessing.graph import graph_from_edgelist, remove_void_types
import networkx as nx
from preprocessing.CorpusManager import CorpusManager
import pickle
from preprocessing.utils import save_data_with_pickle, load_data_with_pickle
import time
import random

# List of classes used to test the correctness of the workflow
# PATH in which utility files are stored
# PICKLES_PATH = '../source_files/pickles/'
PICKLES_PATH = '/datahdd/vmanuel/MTNCI_datasets/source_files/pickles/'

# PATH that refers to the file which let the building of the Ontology Graph
PATH_TO_EDGELIST = '/datahdd/vmanuel/MTNCI_datasets/source_files/pickles/dbpedia_edgelist_no_closure.tsv'
# PATH to the corpus from which information are extracted
CORPUS_PATH = '/datahdd/vmanuel/ELMo/Corpora/shuffled_text_with_words'
LOG = 'MEGAlog_4_3.txt'

FILE_ID = '16_3'

GRAPH_PATH = PICKLES_PATH + FILE_ID + 'graph'
ENTITY_DICT_PATH = PICKLES_PATH + FILE_ID +'entity_dict'
WORD_INDEXES_PATH = PICKLES_PATH + FILE_ID + 'word_indexes'
WORD_OCCURRENCE_INDEX_PATH = PICKLES_PATH + FILE_ID + 'word_occurrence_indexes'
FOUND_ENTITY_DICT_PATH = PICKLES_PATH + FILE_ID + 'found_entity_dict'
FINAL_TREE_PATH = PICKLES_PATH + FILE_ID + 'final_tree'

LENGTH = 100000

avoid_multilabeling = True

# %%
e = EntityNameRetriever()
entity_dict = load_data_with_pickle(ENTITY_DICT_PATH)

# %%
void_types = [t for t, v in entity_dict.items() if v == []]
G = load_data_with_pickle(GRAPH_PATH)
pruned_G = remove_void_types(G, void_types)

# %%
list_of_classes = [n for n in pruned_G.nodes()]

c = CorpusManager()
c.read_corpus(CORPUS_PATH, LENGTH)
c.create_all_entities(entity_dict, concepts=list_of_classes)    
occurrences_of_entities = load_data_with_pickle(WORD_OCCURRENCE_INDEX_PATH)
# Out:
# read input corpus
# 100%|██████████| 100000/100000 [00:04<00:00, 20908.60it/s]
# 283021 words in vocab
# 478745 entities
# 128600 entity-tokens in vocab

# %%
list_of_classes
# Out:
# ['NaturalEvent',
#  'Earthquake',
#  'SolarEclipse',
#  'StormSurge',
#  'Province',
#  'HistoricalProvince',
#  'TimePeriod',
#  'CareerStation',
#  'GeologicalPeriod',
#  'HistoricalPeriod',
#  'PeriodOfArtisticStyle',
#  'PrehistoricalPeriod',
#  'ProtohistoricalPeriod',
#  'Year',
#  'YearInSpaceflight',
#  'AnatomicalStructure',
#  'Artery',
#  'BloodVessel',
#  'Bone',
#  'Brain',
#  'Embryology',
#  'Ligament',
#  'Lymph',
#  'Muscle',
#  'Nerve',
#  'Vein',
#  'Territory',
#  'OldTerritory',
#  'Beverage',
#  'Beer',
#  'Vodka',
#  'Wine',
#  'ControlledDesignationOfOriginWine',
#  'Department',
#  'OverseasDepartment',
#  'SportsSeason',
#  'MotorsportSeason',
#  'SportsTeamSeason',
#  'BaseballSeason',
#  'FootballLeagueSeason',
#  'NCAATeamSeason',
#  'SoccerClubSeason',
#  'SoccerLeagueSeason',
#  'FloweringPlant',
#  'Grape',
#  'SportCompetitionResult',
#  'OlympicResult',
#  'SnookerWorldRanking',
#  'Tower',
#  'Lighthouse',
#  'WaterTower',
#  'ReligiousBuilding',
#  'Abbey',
#  'Church',
#  'Monastery',
#  'Mosque',
#  'Shrine',
#  'Synagogue',
#  'Temple',
#  'MotorcycleRider',
#  'MotocycleRacer',
#  'SpeedwayRider',
#  'ClericalAdministrativeRegion',
#  'Deanery',
#  'Diocese',
#  'Parish',
#  'PowerStation',
#  'NuclearPowerStation',
#  'Name',
#  'GivenName',
#  'Surname',
#  'Instrumentalist',
#  'Guitarist',
#  'Company',
#  'Airline',
#  'Bank',
#  'Brewery',
#  'BusCompany',
#  'Caterer',
#  'LawFirm',
#  'Publisher',
#  'RecordLabel',
#  'Winery',
#  'Wrestler',
#  'SumoWrestler',
#  'GridironFootballPlayer',
#  'AmericanFootballPlayer',
#  'CanadianFootballPlayer',
#  'Engine',
#  'AutomobileEngine',
#  'RocketEngine',
#  'GeneLocation',
#  'HumanGeneLocation',
#  'MouseGeneLocation',
#  'TheologicalConcept',
#  'ChristianDoctrine',
#  'Settlement',
#  'City',
#  'CityDistrict',
#  'HistoricalSettlement',
#  'Town',
#  'Village',
#  'Capital',
#  'CapitalOfRegion',
#  'Software',
#  'VideoGame',
#  'RacingDriver',
#  'DTMRacer',
#  'FormulaOneRacer',
#  'NascarDriver',
#  'RallyDriver',
#  'ArchitecturalStructure',
#  'AmusementParkAttraction',
#  'Arena',
#  'Building',
#  'Gate',
#  'Infrastructure',
#  'MilitaryStructure',
#  'Mill',
#  'Pyramid',
#  'SportFacility',
#  'Square',
#  'Tunnel',
#  'Venue',
#  'Zoo',
#  'RollerCoaster',
#  'WaterRide',
#  'Casino',
#  'Castle',
#  'Factory',
#  'HistoricBuilding',
#  'Hospital',
#  'Hotel',
#  'Library',
#  'Museum',
#  'Prison',
#  'Restaurant',
#  'ShoppingMall',
#  'Skyscraper',
#  'Airport',
#  'Dam',
#  'Dike',
#  'LaunchPad',
#  'Lock',
#  'Port',
#  'RestArea',
#  'RouteOfTransportation',
#  'Station',
#  'Fort',
#  'Treadmill',
#  'Watermill',
#  'WindMotor',
#  'Windmill',
#  'CricketGround',
#  'GolfCourse',
#  'RaceTrack',
#  'SkiArea',
#  'Stadium',
#  'Theatre',
#  'Event',
#  'Competition',
#  'LifeCycleEvent',
#  'SocietalEvent',
#  'Contest',
#  'PersonalEvent',
#  'AcademicConference',
#  'Attack',
#  'Convention',
#  'Election',
#  'FilmFestival',
#  'Meeting',
#  'MilitaryConflict',
#  'MusicFestival',
#  'Rebellion',
#  'SpaceMission',
#  'SportsEvent',
#  'Country',
#  'HistoricalCountry',
#  'OrganisationMember',
#  'SportsTeamMember',
#  'Case',
#  'LegalCase',
#  'SupremeCourtOfTheUnitedStatesCase',
#  'Boxer',
#  'AmateurBoxer',
#  'Island',
#  'Atoll',
#  'NaturalPlace',
#  'Archipelago',
#  'Beach',
#  'BodyOfWater',
#  'Cape',
#  'Cave',
#  'Crater',
#  'Desert',
#  'Forest',
#  'Glacier',
#  'HotSpring',
#  'Mountain',
#  'MountainPass',
#  'MountainRange',
#  'Valley',
#  'Volcano',
#  'Bay',
#  'Lake',
#  'Ocean',
#  'Sea',
#  'Stream',
#  'LunarCrater',
#  'Canal',
#  'Creek',
#  'River',
#  'SportsManager',
#  'SoccerManager',
#  'Coach',
#  'AmericanFootballCoach',
#  'CollegeCoach',
#  'VolleyballCoach',
#  'Writer',
#  'Historian',
#  'MusicComposer',
#  'PlayWright',
#  'Poet',
#  'ScreenWriter',
#  'SongWriter',
#  'Swarm',
#  'Globularswarm',
#  'Openswarm',
#  'TeamSport',
#  'Soccer',
#  'Politician',
#  'Chancellor',
#  'Congressman',
#  'Deputy',
#  'Governor',
#  'Lieutenant',
#  'Mayor',
#  'MemberOfParliament',
#  'President',
#  'PrimeMinister',
#  'Senator',
#  'VicePresident',
#  'VicePrimeMinister',
#  'TelevisionPersonality',
#  'Host',
#  'Device',
#  'Camera',
#  'InformationAppliance',
#  'Instrument',
#  'MobilePhone',
#  'Weapon',
#  'DigitalCamera',
#  'Guitar',
#  'Organ',
#  'Artwork',
#  'Painting',
#  'Sculpture',
#  'VolleyballPlayer',
#  'BeachVolleyballPlayer',
#  'Non-ProfitOrganisation',
#  'RecordOffice',
#  'Cleric',
#  'Cardinal',
#  'ChristianBishop',
#  'ChristianPatriarch',
#  'Pope',
#  'Priest',
#  'Saint',
#  'Vicar',
#  'Region',
#  'AdministrativeRegion',
#  'HistoricalRegion',
#  'NaturalRegion',
#  'GovernmentalAdministrativeRegion',
#  'HistoricalAreaOfAuthority',
#  'SnookerPlayer',
#  'SnookerChamp',
#  'PersonFunction',
#  'PoliticalFunction',
#  'Profession',
#  'MusicalArtist',
#  'BackScene',
#  'ClassicalMusicArtist',
#  'MusicDirector',
#  'Singer',
#  'Presenter',
#  'RadioHost',
#  'TelevisionHost',
#  'Database',
#  'BiologicalDatabase',
#  'MusicalWork',
#  'Album',
#  'ArtistDiscography',
#  'ClassicalMusicComposition',
#  'Musical',
#  'NationalAnthem',
#  'Opera',
#  'Single',
#  'Song',
#  'EurovisionSongContestEntry',
#  'MeanOfTransportation',
#  'Aircraft',
#  'Automobile',
#  'Locomotive',
#  'MilitaryVehicle',
#  'Motorcycle',
#  'On-SiteTransportation',
#  'Rocket',
#  'Ship',
#  'SpaceShuttle',
#  'SpaceStation',
#  'Spacecraft',
#  'Train',
#  'TrainCarriage',
#  'Tram',
#  'MilitaryAircraft',
#  'ConveyorSystem',
#  'Escalator',
#  'MovingWalkway',
#  'Annotation',
#  'Reference',
#  'UnitOfWork',
#  'Project',
#  'ResearchProject',
#  'MotorsportRacer',
#  'Gene',
#  'HumanGene',
#  'MouseGene',
#  'Satellite',
#  'ArtificialSatellite',
#  'GovernmentAgency',
#  'GovernmentCabinet',
#  'Horse',
#  'RaceHorse',
#  'PeriodicalLiterature',
#  'AcademicJournal',
#  'Magazine',
#  'Newspaper',
#  'UndergroundJournal',
#  'Plant',
#  'ClubMoss',
#  'Conifer',
#  'CultivatedVariety',
#  'Cycad',
#  'Fern',
#  'Ginkgo',
#  'Gnetophytes',
#  'GreenAlga',
#  'Moss',
#  'SkiResort',
#  'Athlete',
#  'ArcherPlayer',
#  'AthleticsPlayer',
#  'AustralianRulesFootballPlayer',
#  'BadmintonPlayer',
#  'BaseballPlayer',
#  'BasketballPlayer',
#  'Bodybuilder',
#  'BullFighter',
#  'Canoeist',
#  'ChessPlayer',
#  'Cricketer',
#  'Cyclist',
#  'DartsPlayer',
#  'Fencer',
#  'GaelicGamesPlayer',
#  'GolfPlayer',
#  'Gymnast',
#  'HandballPlayer',
#  'HighDiver',
#  'HorseRider',
#  'Jockey',
#  'LacrossePlayer',
#  'MartialArtist',
#  'NationalCollegiateAthleticAssociationAthlete',
#  'NetballPlayer',
#  'PokerPlayer',
#  'Rower',
#  'RugbyPlayer',
#  'SoccerPlayer',
#  'SquashPlayer',
#  'Surfer',
#  'Swimmer',
#  'TableTennisPlayer',
#  'TeamMember',
#  'TennisPlayer',
#  'WaterPoloPlayer',
#  'WinterSportPlayer',
#  'Biathlete',
#  'BobsleighAthlete',
#  'CrossCountrySkier',
#  'Curler',
#  'FigureSkater',
#  'IceHockeyPlayer',
#  'NordicCombined',
#  'Skater',
#  'Skijumper',
#  'Skier',
#  'SpeedSkater',
#  'WrittenWork',
#  'Article',
#  'Book',
#  'Comic',
#  'Drama',
#  'Law',
#  'Letter',
#  'MultiVolumePublication',
#  'Play',
#  'Poem',
#  'Quote',
#  'Resume',
#  'StatedResolution',
#  'Treaty',
#  'Novel',
#  'ComicStrip',
#  'Manga',
#  'Manhua',
#  'Manhwa',
#  'Royalty',
#  'BritishRoyalty',
#  'Baronet',
#  'Family',
#  'NobleFamily',
#  'Sport',
#  'Athletics',
#  'Boxing',
#  'HorseRiding',
#  'BoxingCategory',
#  'BoxingStyle',
#  'Activity',
#  'Game',
#  'Sales',
#  'BoardGame',
#  'CardGame',
#  'Olympics',
#  'OlympicEvent',
#  'Food',
#  'Cheese',
#  'SportsClub',
#  'HockeyClub',
#  'Work',
#  'Cartoon',
#  'CollectionOfValuables',
#  'Document',
#  'Film',
#  'LineOfFashion',
#  'RadioProgram',
#  'TelevisionEpisode',
#  'TelevisionSeason',
#  'TelevisionShow',
#  'Website',
#  'Anime',
#  'HollywoodCartoon',
#  'Archive',
#  'File',
#  'Image',
#  'Sound',
#  'CyclingCompetition',
#  'FootballMatch',
#  'GrandPrix',
#  'InternationalFootballLeagueEvent',
#  'MixedMartialArtsEvent',
#  'NationalFootballLeagueEvent',
#  'Race',
#  'Tournament',
#  'WrestlingEvent',
#  'LightNovel',
#  'Language',
#  'ProgrammingLanguage',
#  'Actor',
#  'AdultActor',
#  'VoiceActor',
#  'Group',
#  'Band',
#  'ComedyGroup',
#  'Birth',
#  'Death',
#  'Divorce',
#  'Marriage',
#  'GolfTournament',
#  'SoccerTournament',
#  'TennisTournament',
#  'WomensTennisAssociationTournament',
#  'SportsLeague',
#  'AmericanFootballLeague',
#  'AustralianFootballLeague',
#  'AutoRacingLeague',
#  'BaseballLeague',
#  'BasketballLeague',
#  'BowlingLeague',
#  'BoxingLeague',
#  'CanadianFootballLeague',
#  'CricketLeague',
#  'CurlingLeague',
#  'CyclingLeague',
#  'FieldHockeyLeague',
#  'FormulaOneRacing',
#  'GolfLeague',
#  'HandballLeague',
#  'IceHockeyLeague',
#  'InlineHockeyLeague',
#  'LacrosseLeague',
#  'MixedMartialArtsLeague',
#  'MotorcycleRacingLeague',
#  'PaintballLeague',
#  'PoloLeague',
#  'RadioControlledRacingLeague',
#  'RugbyLeague',
#  'SoccerLeague',
#  'SoftballLeague',
#  'SpeedwayLeague',
#  'TennisLeague',
#  'VideogamesLeague',
#  'VolleyballLeague',
#  'Person',
#  'Ambassador',
#  'Archeologist',
#  'Architect',
#  'Aristocrat',
#  'Artist',
#  'Astronaut',
#  'BeautyQueen',
#  'BusinessPerson',
#  'Celebrity',
#  'Chef',
#  'Criminal',
#  'Economist',
#  'Egyptologist',
#  'Engineer',
#  'Farmer',
#  'FictionalCharacter',
#  'HorseTrainer',
#  'Journalist',
#  'Judge',
#  'Lawyer',
#  'Linguist',
#  'MemberResistanceMovement',
#  'MilitaryPerson',
#  'Model',
#  'Monarch',
#  'MovieDirector',
#  'Noble',
#  'OfficeHolder',
#  'Orphan',
#  'Philosopher',
#  'PlayboyPlaymate',
#  'PoliticianSpouse',
#  'Producer',
#  'Psychologist',
#  'Referee',
#  'Religious',
#  'RomanEmperor',
#  'Scientist',
#  'TelevisionDirector',
#  'TheatreDirector',
#  'Comedian',
#  'ComicsCreator',
#  'Dancer',
#  'FashionDesigner',
#  'Humorist',
#  'Painter',
#  'Photographer',
#  'Sculptor',
#  'Murderer',
#  'ComicsCharacter',
#  'DisneyCharacter',
#  'MythologicalFigure',
#  'NarutoCharacter',
#  'SoapCharacter',
#  'Biologist',
#  'Entomologist',
#  'Medician',
#  'Professor',
#  'Bridge',
#  'RailwayLine',
#  'RailwayTunnel',
#  'Road',
#  'RoadJunction',
#  'RoadTunnel',
#  'WaterwayTunnel',
#  'ElectricalSubstation',
#  'FillingStation',
#  'MetroStation',
#  'RailwayStation',
#  'TramStation',
#  'ReligiousOrganisation',
#  'ClericalOrder',
#  'NationalFootballLeagueSeason',
#  'Award',
#  'Decoration',
#  'NobelPrize',
#  'CelestialBody',
#  'Asteroid',
#  'Constellation',
#  'Galaxy',
#  'Planet',
#  'Star',
#  'BrownDwarf',
#  'Racecourse',
#  'Agent',
#  'Deity',
#  'Employer',
#  'Organisation',
#  'Broadcaster',
#  'EducationalInstitution',
#  'EmployersOrganisation',
#  'GeopoliticalOrganisation',
#  'InternationalOrganisation',
#  'Legislature',
#  'MilitaryUnit',
#  'Parliament',
#  'PoliticalParty',
#  'PublicTransitSystem',
#  'SambaSchool',
#  'SportsTeam',
#  'TermOfOffice',
#  'TradeUnion',
#  'Monument',
#  'GraveMonument',
#  'Memorial',
#  'Arrondissement',
#  'Canton',
#  'District',
#  'DistrictWaterBoard',
#  'MicroRegion',
#  'Municipality',
#  'Prefecture',
#  'Regency',
#  'SubMunicipality',
#  'HistoricalDistrict',
#  'FormerMunicipality',
#  'Eukaryote',
#  'Animal',
#  'Fungus',
#  'Amphibian',
#  'Arachnid',
#  'Bird',
#  'Crustacean',
#  'Fish',
#  'Insect',
#  'Mammal',
#  'Mollusca',
#  'Reptile',
#  'College',
#  'School',
#  'University',
#  'CyclingRace',
#  'HorseRace',
#  'MotorRace',
#  'Relationship',
#  'Ratio',
#  'AmericanFootballTeam',
#  'AustralianFootballTeam',
#  'BaseballTeam',
#  'BasketballTeam',
#  'CanadianFootballTeam',
#  'CricketTeam',
#  'CyclingTeam',
#  'FormulaOneTeam',
#  'HandballTeam',
#  'HockeyTeam',
#  'RugbyClub',
#  'SoccerClub',
#  'SpeedwayTeam',
#  'NationalSoccerClub',
#  'SerialKiller',
#  'Cat',
#  'Dog',
#  'List',
#  'TrackList',
#  'AnimangaCharacter',
#  'Biomolecule',
#  'Enzyme',
#  'Hormone',
#  'Lipid',
#  'Polysaccharide',
#  'Protein',
#  'BroadcastNetwork',
#  'RadioStation',
#  'TelevisionStation',
#  'MovingImage',
#  'StillImage',
#  'Place',
#  'Cemetery',
#  'ConcentrationCamp',
#  'CountrySeat',
#  'Garden',
#  'HistoricPlace',
#  'Mine',
#  'Park',
#  'PopulatedPlace',
#  'ProtectedArea',
#  'SiteOfSpecialScientificInterest',
#  'WineRegion',
#  'WorldHeritageSite',
#  'CoalPit',
#  'Agglomeration',
#  'Community',
#  'Continent',
#  'GatedCommunity',
#  'Intercommunality',
#  'Locality',
#  'State',
#  'Street',
#  'Genre',
#  'ArtisticGenre',
#  'LiteraryGenre',
#  'MovieGenre',
#  'MusicGenre',
#  'ChemicalSubstance',
#  'ChemicalCompound',
#  'ChemicalElement',
#  'Drug',
#  'Mineral',
#  'Species',
#  'Archaea',
#  'Bacteria',
#  'TopicalConcept',
#  'AcademicSubject',
#  'CardinalDirection',
#  'Fashion',
#  'Ideology',
#  'MathematicalConcept',
#  'PhilosophicalConcept',
#  'PoliticalConcept',
#  'ScientificConcept',
#  'Standard',
#  'SystemOfLaw',
#  'Tax',
#  'Taxon',
#  'Type',
#  'DocumentType',
#  'GovernmentType',
#  'Fiefdom',
#  'Thing',
#  'GrossDomesticProduct',
#  'Area',
#  'ChartsPlacements',
#  'EthnicGroup',
#  'Holiday',
#  'Flag',
#  'Colour',
#  'Population',
#  'PenaltyShootOut',
#  'Media',
#  'Blazon',
#  'Altitude',
#  'Currency',
#  'Statistic',
#  'Diploma',
#  'PublicService',
#  'Disease',
#  'GrossDomesticProductPerCapita',
#  'ElectionDiagram',
#  'Demographics',
#  'Medicine',
#  'Unknown',
#  'Polyhedron',
#  'RouteStop',
#  'Depth',
#  'HumanDevelopmentIndex']

# %%
found_entities = set(occurrences_of_entities.keys())
found_entity_dict = {k: set(v).intersection(found_entities) for k,v in entity_dict.items() if set(v).intersection(found_entities)}

# %%
c.word_indexes = load_data_with_pickle(WORD_INDEXES_PATH)

# %%
occurrences_of_entities['aakash']

# %%
found_entity_dict

# %%
c.check_entity_in_row(ENTITY = 'aakash', ROW = 46355, verbose= True)

# %%
from collections import defaultdict

entity_concept_dict =  defaultdict(list)

for concept, entities in found_entity_dict.items():
    for entity in entities:
        entity_concept_dict[entity].append(concept)

# %%
FILTERED_DATASET_PATH = '../source_files/vectors/' + '16_3' + '/fair/' 

E_TRAIN_PATH = FILTERED_DATASET_PATH + 'filtered_entities_train'
E_VAL_PATH = FILTERED_DATASET_PATH + 'filtered_entities_val'
E_TEST_PATH = FILTERED_DATASET_PATH + 'filtered_entities_test'

E_train = load_data_with_pickle(E_TRAIN_PATH)
E_val = load_data_with_pickle(E_VAL_PATH)
E_test = load_data_with_pickle(E_TEST_PATH)

Y_TRAIN_PATH = FILTERED_DATASET_PATH + 'filtered_Y_train'
Y_VAL_PATH = FILTERED_DATASET_PATH + 'filtered_Y_val'
Y_TEST_PATH = FILTERED_DATASET_PATH + 'filtered_Y_test'

Y_train = load_data_with_pickle(Y_TRAIN_PATH)
Y_val = load_data_with_pickle(Y_VAL_PATH)
Y_test = load_data_with_pickle(Y_TEST_PATH)

from collections import defaultdict
entity_dict = defaultdict(list)

for (Y, E) in [(Y_train, E_train), (Y_val, E_val), (Y_test, E_test)]:
    for y, e in zip(Y, E):
        entity_dict[e] = [y]

# %%
len(Y_test)
# Out:
# 11005

# %%
entity_dict
# Out:
# defaultdict(list,
#             {'explorer': ['InformationAppliance'],
#              'acts': ['TelevisionStation'],
#              'brody': ['City'],
#              'peng': ['Comic'],
#              'canadians': ['EthnicGroup'],
#              'brewing': ['Company'],
#              'square': ['ShoppingMall'],
#              'ann': ['TelevisionStation'],
#              'wheel': ['MilitaryUnit'],
#              'species': ['FictionalCharacter'],
#              'heath': ['ProtectedArea'],
#              'network': ['Company'],
#              'island': ['Museum'],
#              'three': ['TelevisionShow'],
#              'man': ['WrittenWork'],
#              'ceremony': ['SportsEvent'],
#              'year': ['Country'],
#              'advance': ['InformationAppliance'],
#              'learning': ['Band'],
#              'gallery': ['Museum'],
#              'parmulariaceae': ['Fungus'],
#              'team': ['SportsLeague'],
#              'army': ['MilitaryUnit'],
#              'copelatus': ['Species'],
#              'talk': ['RadioStation'],
#              'adderley': ['Village'],
#              'punch': ['Comic'],
#              'tolu': ['Town'],
#              'family': ['Band'],
#              'diet': ['Legislature'],
#              'software': ['TelevisionShow'],
#              'zone': ['Mountain'],
#              'name': ['Protein'],
#              'drug': ['ChemicalCompound'],
#              'society': ['Band'],
#              'language': ['Disease'],
#              'person': ['Drug'],
#              'dore': ['Village'],
#              'brooks': ['SoccerClub'],
#              'clan lockhart': ['EthnicGroup'],
#              'cantopop': ['MusicGenre'],
#              'links': ['Single'],
#              'hip': ['AnatomicalStructure'],
#              'uncle': ['Person'],
#              'science': ['MusicalWork'],
#              'party': ['PoliticalParty'],
#              'variations': ['Play'],
#              'fountain': ['MusicalWork'],
#              'buffalo': ['Film'],
#              'utricularia': ['Species'],
#              'side': ['City'],
#              'women': ['Film'],
#              'street': ['Road'],
#              'echelon': ['TelevisionShow'],
#              'skalvians': ['Language'],
#              'terrier': ['FictionalCharacter'],
#              'corporal': ['Plant'],
#              'transmitter': ['Device'],
#              'washington': ['Ship'],
#              'discipline': ['MilitaryConflict'],
#              'military': ['MilitaryUnit'],
#              'publishing': ['Election'],
#              'darren osborne': ['FictionalCharacter'],
#              'helmstedt': ['City'],
#              'days': ['TelevisionShow'],
#              'movement': ['PoliticalParty'],
#              'sol duc river': ['BodyOfWater'],
#              'census': ['AnatomicalStructure'],
#              'fishing': ['Sport'],
#              'massacre': ['MilitaryConflict'],
#              'labeo niloticus': ['Fish'],
#              'footage': ['ChemicalCompound'],
#              'sri': ['Food'],
#              'open': ['Event'],
#              'tower': ['ArchitecturalStructure'],
#              'era': ['Bridge'],
#              'identified': ['Album'],
#              'west': ['Country'],
#              'lot': ['ShoppingMall'],
#              'public': ['Event'],
#              'collect': ['Song'],
#              'hippopsis': ['Insect'],
#              'arbeter fraynd': ['Newspaper'],
#              'vaudeville': ['MusicGenre'],
#              'raju': ['EthnicGroup'],
#              'metres': ['SportsEvent'],
#              'focus': ['Language'],
#              'weevil': ['Species'],
#              'group': ['Drug'],
#              'phoca': ['Mammal'],
#              'russ davis': ['BaseballPlayer'],
#              'region': ['Settlement'],
#              'phoenicurus': ['Bird'],
#              'venkatraman ramakrishnan': ['Scientist'],
#              'two': ['Organisation'],
#              'karl': ['RadioStation'],
#              'populous': ['VideoGame'],
#              'argonauts': ['Band'],
#              'https': ['Software'],
#              'present': ['SportsEvent'],
#              'concert': ['Album'],
#              'ship': ['Ship'],
#              'upper': ['Beverage'],
#              'crypturellus': ['Bird'],
#              'owned': ['Food'],
#              'uss dixie': ['Ship'],
#              'north coventry township chester county pennsylvania': ['Town'],
#              'mead': ['Beverage'],
#              'service': ['Organisation'],
#              'championship': ['SoccerTournament'],
#              'law': ['Device'],
#              'movie': ['Film'],
#              'bassist': ['MusicalArtist'],
#              'boat': ['Ship'],
#              'mens': ['MythologicalFigure'],
#              'feis': ['ArchitecturalStructure'],
#              'nashville': ['SportsEvent'],
#              'upper great southern football league': ['SportsLeague'],
#              'cousin': ['Animal'],
#              'mario': ['FictionalCharacter'],
#              'england': ['MusicalArtist'],
#              'house': ['HistoricPlace'],
#              'road': ['Road'],
#              'germans': ['EthnicGroup'],
#              'big sandy rancheria': ['EthnicGroup'],
#              'sprint': ['VideoGame'],
#              'palestinian communist party': ['PoliticalParty'],
#              'saloninus': ['Royalty'],
#              'little': ['SportsEvent'],
#              'figure': ['Comic'],
#              'canyon': ['Place'],
#              'salami': ['Food'],
#              'conquest': ['Fashion'],
#              'cam ranh': ['City'],
#              'jack': ['Cricketer'],
#              'prince': ['Person'],
#              'bar': ['Automobile'],
#              'history': ['Book'],
#              'car': ['Device'],
#              'country': ['Settlement'],
#              'effectiveness': ['Weapon'],
#              'bee': ['Insect'],
#              'polen': ['EthnicGroup'],
#              'genus': ['Plant'],
#              'kondratowice': ['Village'],
#              'mara': ['MythologicalFigure'],
#              'addition': ['MilitaryConflict'],
#              'frederick casimir kettler': ['Royalty'],
#              'ati vishisht seva medal': ['Award'],
#              'gaillardia': ['Species'],
#              'richard lewontin': ['Scientist'],
#              'jack dempsey': ['Person'],
#              'biosphere': ['ArchitecturalStructure'],
#              'color': ['Building'],
#              'clover mountains': ['MountainRange'],
#              'small': ['Language'],
#              'catshill': ['Village'],
#              'single malt scotch': ['Beverage'],
#              'raptors': ['SportsTeam'],
#              'xavier woods': ['Athlete'],
#              'legacy': ['SoccerClub'],
#              'dornier flugzeugwerke': ['Company'],
#              'salon': ['Museum'],
#              'psalms': ['Book'],
#              'armenia': ['Event'],
#              'qanawat': ['Village'],
#              'light': ['Species'],
#              'monday': ['School'],
#              'mark': ['Protein'],
#              'son': ['Weapon'],
#              'education': ['Election'],
#              'captain': ['Bank'],
#              'block': ['Venue'],
#              'petrus camper': ['Scientist'],
#              'uf health shands hospital': ['Hospital'],
#              'jewel': ['RecordLabel'],
#              'communication': ['Band'],
#              'settlers': ['Event'],
#              'playoffs': ['SoccerTournament'],
#              'nick larkin': ['Cricketer'],
#              'billboard': ['Building'],
#              'reservoir': ['Lake'],
#              'sister': ['Mammal'],
#              'aarti': ['EthnicGroup'],
#              'zalaegerszegi te': ['SportsTeam'],
#              'cinema': ['Venue'],
#              'down': ['Comic'],
#              'surface': ['Device'],
#              'knights': ['Comic'],
#              'commerce': ['Sport'],
#              'arthur kornberg': ['Scientist'],
#              'result': ['Disease'],
#              'seat': ['Automobile'],
#              'beetle': ['Species'],
#              'fox': ['Species'],
#              'plantation': ['MusicalWork'],
#              'broadway': ['HistoricPlace'],
#              'legion': ['Book'],
#              'butte': ['Mountain'],
#              'foot': ['AnatomicalStructure'],
#              'kukherd': ['City'],
#              'baja': ['SportsEvent'],
#              'dyfed': ['AdministrativeRegion'],
#              'orchestra': ['Band'],
#              'alkane stereochemistry': ['Film'],
#              'electron': ['Scientist'],
#              'mike caro': ['Athlete'],
#              'kevan jones': ['Politician'],
#              'mick taylor': ['Artist'],
#              'diplomatic bag': ['Company'],
#              'marble': ['Band'],
#              'pak': ['Weapon'],
#              'professional': ['Person'],
#              'force': ['MilitaryPerson'],
#              'piet norval': ['Athlete'],
#              'total': ['WrittenWork'],
#              'knott': ['Mountain'],
#              'cooperation': ['Election'],
#              'stories': ['Play'],
#              'ash': ['Food'],
#              'chasse': ['MilitaryConflict'],
#              'lady': ['Comic'],
#              'topography': ['Book'],
#              'top countdown': ['TelevisionShow'],
#              'kosambi': ['City'],
#              'lies': ['RecordLabel'],
#              'drop': ['VideoGame'],
#              'rita marley': ['Artist'],
#              'centre': ['Venue'],
#              'citrus': ['Species'],
#              'linjeflyg': ['Airline'],
#              'working': ['WrittenWork'],
#              'ensemble': ['Weapon'],
#              'fulmer': ['Village'],
#              'foxhound': ['MythologicalFigure'],
#              'december': ['MusicalWork'],
#              'walter': ['Venue'],
#              'nebelhorn': ['Mountain'],
#              'real': ['Album'],
#              'john': ['Single'],
#              'well': ['MusicalWork'],
#              'wolstanton': ['Village'],
#              'sombor': ['City'],
#              'mohammad sattarpour': ['Boxer'],
#              'acting': ['Book'],
#              'town': ['Settlement'],
#              'poland': ['Place'],
#              'saturday': ['School'],
#              'hiren varaiya': ['Cricketer'],
#              'jos': ['City'],
#              'spring': ['Magazine'],
#              'rac tourist trophy': ['Award'],
#              'miles': ['MusicalWork'],
#              'metro station': ['Station'],
#              'carbide': ['ChemicalCompound'],
#              'coalition': ['MilitaryPerson'],
#              'six': ['Protein'],
#              'rice': ['Plant'],
#              'village': ['Settlement'],
#              'goalkeeper': ['Athlete'],
#              'heteropoda': ['Arachnid'],
#              'squadron': ['Film'],
#              'rugby': ['VideoGame'],
#              'baron': ['Award'],
#              'competition': ['Organisation'],
#              'alma': ['Language'],
#              'president': ['Person'],
#              'category': ['TelevisionStation'],
#              'affordable housing': ['Building'],
#              'determine': ['Mammal'],
#              'arm': ['AnatomicalStructure'],
#              'anniversary': ['School'],
#              'vahase': ['Island'],
#              'kris keating': ['RugbyPlayer'],
#              'champion': ['Album'],
#              'market': ['Island'],
#              'murder': ['MilitaryConflict'],
#              'zfyve': ['Protein'],
#              'snap': ['Drug'],
#              'industry': ['Company'],
#              'congress': ['OfficeHolder'],
#              'usa': ['Ship'],
#              'museum': ['Protein'],
#              'nasjonal samling': ['PoliticalParty'],
#              'self': ['AdministrativeRegion'],
#              'nick lowe': ['Artist'],
#              'association': ['PoliticalParty'],
#              'wholesale': ['Company'],
#              'fluid': ['ChemicalCompound'],
#              'daai chin': ['EthnicGroup'],
#              'swedes': ['EthnicGroup'],
#              'anugerah musik indonesia': ['Award'],
#              'contest': ['Country'],
#              'arabs': ['EthnicGroup'],
#              'temple': ['Building'],
#              'ring': ['Disease'],
#              'funeral': ['Award'],
#              'independence': ['Disease'],
#              'arabic': ['Language'],
#              'video': ['Athlete'],
#              'joe': ['TelevisionShow'],
#              'ferrymead heritage park': ['Museum'],
#              'daughter': ['Mammal'],
#              'take': ['Album'],
#              'navajo': ['EthnicGroup'],
#              'sea': ['Organisation'],
#              'pilot': ['Language'],
#              'synagogue': ['Building'],
#              'international': ['Automobile'],
#              'wire': ['Single'],
#              'sigma': ['RadioStation'],
#              'internet': ['AnatomicalStructure'],
#              'aisne': ['Place'],
#              'sabotage': ['MilitaryConflict'],
#              'mormyrus': ['Fish'],
#              'tenure': ['River'],
#              'jurala project': ['PowerStation'],
#              'concrete': ['ChemicalCompound'],
#              'westfield westcity': ['ShoppingMall'],
#              'test': ['Cricketer'],
#              'chattanooga campaign': ['Event'],
#              'camel wrestling': ['Sport'],
#              'kilometres': ['Aircraft'],
#              'kanhoji angre': ['MilitaryPerson'],
#              'steinitz goby': ['Fish'],
#              'term': ['Ship'],
#              'tournament': ['SoccerTournament'],
#              'gila bend mountains': ['MountainRange'],
#              'store': ['Town'],
#              'happy': ['Comic'],
#              'aculeata': ['Species'],
#              'herbert payne': ['Politician'],
#              'feet': ['RecordLabel'],
#              'nanda': ['Surname'],
#              'studios': ['RecordLabel'],
#              'maurice richard arena': ['Venue'],
#              'films': ['RecordLabel'],
#              'sheridan': ['Beverage'],
#              'wales': ['MusicalArtist'],
#              'dorney park wildwater kingdom': ['Film'],
#              'daniel gorenstein': ['Scientist'],
#              'artillery': ['Weapon'],
#              'watercress darter national wildlife refuge': ['ProtectedArea'],
#              'invective': ['Language'],
#              'theatre': ['TelevisionShow'],
#              'tributary': ['River'],
#              'recorder': ['ComicsCharacter'],
#              'arts': ['Protein'],
#              'clay': ['Band'],
#              'colonel': ['Plant'],
#              'parliament': ['Organisation'],
#              'brother': ['Mammal'],
#              'sect': ['EthnicGroup'],
#              'evil': ['Disease'],
#              'ink': ['Protein'],
#              'sole': ['Artist'],
#              'dive': ['Comic'],
#              'curtana': ['Weapon'],
#              'wall': ['Building'],
#              'owlpen manor': ['Building'],
#              'aquatic respiration': ['Election'],
#              'professor': ['Plant'],
#              'festival': ['SportsEvent'],
#              'mall': ['ShoppingMall'],
#              'technology': ['Book'],
#              'maple': ['Species'],
#              'challenge': ['Newspaper'],
#              'botai culture': ['Magazine'],
#              'malm': ['Village'],
#              'word': ['MilitaryUnit'],
#              'jaki byard': ['Artist'],
#              'oliver miller': ['BasketballPlayer'],
#              'warsaw': ['Place'],
#              'bridge': ['Building'],
#              'expense': ['River'],
#              'mix': ['InformationAppliance'],
#              'confluence': ['OfficeHolder'],
#              'rifle': ['Weapon'],
#              'peak': ['Mountain'],
#              'rainbow': ['Device'],
#              'disc dog': ['Sport'],
#              'neolithic': ['Country'],
#              'aitana': ['MountainRange'],
#              'tribute': ['MemberOfParliament'],
#              'initiative': ['Software'],
#              'while': ['Food'],
#              'xilinx': ['Organisation'],
#              'code division multiple access': ['Software'],
#              'latin': ['Language'],
#              'beauty': ['Food'],
#              'throne': ['Settlement'],
#              'honeysuckle': ['Species'],
#              'patient safety': ['Sport'],
#              'idaho gem': ['Mammal'],
#              'panic': ['Disease'],
#              'marina': ['Language'],
#              'concordat': ['Convention'],
#              'ionization': ['Election'],
#              'luis de los santos': ['BaseballPlayer'],
#              'parquesur': ['ShoppingMall'],
#              'roderick chase': ['Cyclist'],
#              'battle': ['VideoGame'],
#              'latacunga': ['City'],
#              'bear': ['Mammal'],
#              'kristina lapina': ['Gymnast'],
#              'budapest': ['Place'],
#              'lysander': ['MilitaryPerson'],
#              'giant featherback': ['Fish'],
#              'individual': ['Person'],
#              'revolution': ['MusicalWork'],
#              'babu': ['SoccerPlayer'],
#              'overall': ['Fashion'],
#              'chardonnay': ['Species'],
#              'rus': ['Newspaper'],
#              'cup': ['Company'],
#              'stage': ['Event'],
#              'sar': ['Device'],
#              'perry': ['Beverage'],
#              'bothwell': ['Village'],
#              'gymnastics': ['Sport'],
#              'path': ['AnatomicalStructure'],
#              'city': ['Settlement'],
#              'factor': ['Software'],
#              'hal': ['Weapon'],
#              'transshipment': ['Company'],
#              'tantra': ['Food'],
#              'adjutant': ['Plant'],
#              'utility': ['Software'],
#              'islam': ['EthnicGroup'],
#              'han': ['EthnicGroup'],
#              'mahoney lake': ['ProtectedArea'],
#              'mr marmalade': ['Play'],
#              'universiade': ['SportsEvent'],
#              'skate': ['VideoGame'],
#              'badminton horse trials': ['Event'],
#              'fair': ['Convention'],
#              'novel': ['WrittenWork'],
#              'lopez': ['Surname'],
#              'intercontinental': ['Company'],
#              'bat': ['Protein'],
#              'dawei': ['City'],
#              'cheese': ['Food'],
#              'neotelphusa': ['Insect'],
#              'agm': ['Device'],
#              'santo': ['Athlete'],
#              'councillor': ['Person'],
#              'qrendi': ['Village'],
#              'general': ['Food'],
#              'sustainability': ['ArchitecturalStructure'],
#              'pitcher': ['Athlete'],
#              'housing': ['Building'],
#              'prevent': ['Sport'],
#              'ukraine': ['Place'],
#              'stenalia': ['Animal'],
#              'limpet': ['Mollusca'],
#              'twin': ['Mammal'],
#              'colebrookdale railroad': ['PublicTransitSystem'],
#              'gurjar': ['EthnicGroup'],
#              'collection': ['Album'],
#              'manufacturing': ['Company'],
#              'commune': ['Settlement'],
#              'architecture': ['Company'],
#              'giovanni battista piranesi': ['Artist'],
#              'type': ['Device'],
#              'rudolf tobias': ['Artist'],
#              'druze': ['Band'],
#              'unity': ['RadioStation'],
#              'cathedral': ['Building'],
#              'paos': ['Village'],
#              'thomas ramsay': ['PoliticalParty'],
#              'afc kairat': ['SportsTeam'],
#              'rana': ['Mountain'],
#              'stadium': ['Settlement'],
#              'pick': ['Protein'],
#              'council': ['Band'],
#              'boomerang': ['Software'],
#              'william scott vare': ['Politician'],
#              'inipi': ['Award'],
#              'energy': ['Building'],
#              'writer': ['Person'],
#              'parish': ['Organisation'],
#              'fireproofing': ['TelevisionShow'],
#              'drilling': ['Election'],
#              'sindhis': ['EthnicGroup'],
#              'invasion': ['MilitaryConflict'],
#              'routing': ['Election'],
#              'francis': ['Ship'],
#              'tuesday': ['School'],
#              'economist': ['Person'],
#              'dog': ['Mammal'],
#              'muted': ['Protein'],
#              'visual': ['InformationAppliance'],
#              'whitecaps fc': ['SportsTeam'],
#              'wsbm': ['RadioStation'],
#              'sunday': ['School'],
#              'favourite': ['Person'],
#              'sharqi': ['MythologicalFigure'],
#              'lobos island': ['Island'],
#              'narran river': ['BodyOfWater'],
#              'treasury': ['Person'],
#              'musculium': ['Mollusca'],
#              'psalter': ['Book'],
#              'siege': ['MilitaryConflict'],
#              'father': ['Organisation'],
#              'great': ['Language'],
#              'australia': ['Place'],
#              'toy': ['Food'],
#              'heritage': ['Magazine'],
#              'poet': ['Person'],
#              'lead': ['MilitaryUnit'],
#              'wednesday': ['Artist'],
#              'episodes': ['Album'],
#              'wife': ['Person'],
#              'pat tillman': ['MilitaryPerson'],
#              'catalyst': ['BaseballPlayer'],
#              'oriental pied hornbill': ['Animal'],
#              'award': ['Person'],
#              'planet': ['Film'],
#              'shore': ['Venue'],
#              'club': ['ArchitecturalStructure'],
#              'cruiser': ['Ship'],
#              'arsenal': ['Aircraft'],
#              'plaza': ['ShoppingMall'],
#              'comino': ['Island'],
#              'best': ['Protein'],
#              'scotland': ['MusicalArtist'],
#              'franciscan': ['EthnicGroup'],
#              'crossmaglen': ['Village'],
#              'basic': ['Language'],
#              'kamyaran': ['City'],
#              'vernacular': ['Language'],
#              'zona': ['Fish'],
#              'tcf': ['Protein'],
#              'bore': ['Weapon'],
#              'mound': ['HistoricPlace'],
#              'odiham': ['Village'],
#              'cumberland': ['AdministrativeRegion'],
#              'sustainable development technology canada': ['GovernmentAgency'],
#              'court': ['GovernmentAgency'],
#              'land': ['MusicalWork'],
#              'york': ['Place'],
#              'deborah kerr': ['Film'],
#              'ran': ['FictionalCharacter'],
#              'wrestler': ['Athlete'],
#              'lavaca river': ['River'],
#              'leap': ['Weapon'],
#              'lucilla': ['Royalty'],
#              'cape': ['Fashion'],
#              'epidemiology': ['Book'],
#              'nelson dewey state park': ['ProtectedArea'],
#              'jean alavoine': ['Cyclist'],
#              'lethal weapon film series': ['TelevisionShow'],
#              'maurice novel': ['WrittenWork'],
#              'southwestern law school': ['EducationalInstitution'],
#              'pitt meadows airport': ['Airport'],
#              'beyond': ['Comic'],
#              'vandals': ['Insect'],
#              'choir': ['Comic'],
#              'prism': ['MilitaryUnit'],
#              'ahjumawi lava springs state park': ['ProtectedArea'],
#              'ornativalva': ['Insect'],
#              'company': ['Organisation'],
#              'oppland': ['AdministrativeRegion'],
#              'ernest gimson': ['Architect'],
#              'transformers': ['SportsTeam'],
#              'thoroughbred': ['Mammal'],
#              'chapter': ['Song'],
#              'genu recurvatum': ['Disease'],
#              'idaho': ['Place'],
#              'sid': ['Town'],
#              'ronald montagu burrows': ['Scientist'],
#              'eden': ['Comic'],
#              'commander': ['Plant'],
#              'product': ['Food'],
#              'scholarship': ['Award'],
#              'zinc': ['Drug'],
#              'steam': ['Building'],
#              'ryan malloy': ['FictionalCharacter'],
#              'disease': ['Disease'],
#              'millfield': ['EducationalInstitution'],
#              'votes': ['EthnicGroup'],
#              'lamb': ['Beverage'],
#              'taxon': ['Band'],
#              'uden': ['Town'],
#              'second': ['Organisation'],
#              'pierre de villiers': ['MilitaryPerson'],
#              'henry arnold karo': ['MilitaryPerson'],
#              'victor steinbrueck': ['Architect'],
#              'urchfont': ['Village'],
#              'queen': ['ArchitecturalStructure'],
#              'eagle': ['Species'],
#              'yat': ['RadioStation'],
#              'honam': ['Settlement'],
#              'pipil people': ['EthnicGroup'],
#              'ontario': ['Settlement'],
#              'wardha': ['City'],
#              'tom': ['Protein'],
#              'micklefield': ['Village'],
#              'cancer': ['Disease'],
#              'snake': ['Reptile'],
#              'urdu': ['Language'],
#              'round': ['Album'],
#              'kincardineshire': ['AdministrativeRegion'],
#              'santiago': ['Place'],
#              'recreation': ['Sport'],
#              'micro': ['WrittenWork'],
#              'storm': ['Aircraft'],
#              'scarabeo': ['Mollusca'],
#              'mike': ['FictionalCharacter'],
#              'mai': ['Aircraft'],
#              'turning': ['Election'],
#              'jet': ['Airline'],
#              'mar': ['Device'],
#              'tobacco': ['Software'],
#              'envoy enterprises': ['Museum'],
#              'constantinople': ['City'],
#              'post': ['SportsEvent'],
#              'pga': ['Protein'],
#              'khomeyn': ['City'],
#              'dot': ['Weapon'],
#              'spouse': ['Person'],
#              'bonthainia': ['Arachnid'],
#              'batman confidential': ['Comic'],
#              'richard osborne': ['AustralianRulesFootballPlayer'],
#              'digamma': ['RadioStation'],
#              'pawtucket rangers': ['SportsTeam'],
#              'coushatta': ['EthnicGroup'],
#              'dance': ['MusicalWork'],
#              'roman catholic high school': ['EducationalInstitution'],
#              'chrysopsis gossypina': ['Species'],
#              'placekicker': ['Athlete'],
#              'jack blades': ['Artist'],
#              'per': ['Drug'],
#              'gravity': ['Disease'],
#              'diaspora': ['EthnicGroup'],
#              'sanitation': ['Software'],
#              'project': ['Software'],
#              'michael houser': ['Artist'],
#              'mathematics': ['Book'],
#              'arrest': ['Band'],
#              'maggie barry': ['Politician'],
#              'developmental linguistics': ['Book'],
#              'manitoba bisons': ['SportsTeam'],
#              'girl': ['Person'],
#              'translations': ['Play'],
#              'get': ['Beverage'],
#              'height': ['Software'],
#              'chesed': ['Food'],
#              'woodworking': ['Sport'],
#              'nage': ['EthnicGroup'],
#              'bernardim freire de andrade': ['MilitaryPerson'],
#              'arch': ['Building'],
#              'priory': ['ReligiousBuilding'],
#              'subsidiary': ['Company'],
#              'elitserien': ['SportsLeague'],
#              'agent': ['FictionalCharacter'],
#              'cant': ['Aircraft'],
#              'nom': ['Food'],
#              'elbasan': ['City'],
#              'farsa': ['MusicGenre'],
#              'parkway': ['Road'],
#              'ottawa': ['Place'],
#              'cider': ['Beverage'],
#              'yorkshire': ['SportsLeague'],
#              'shooting': ['Band'],
#              'existence': ['Book'],
#              'artist': ['Person'],
#              'haggis': ['Food'],
#              'chavacano': ['Language'],
#              'blackout': ['Album'],
#              'studio': ['Place'],
#              'ayrshire': ['AdministrativeRegion'],
#              'narthex': ['MilitaryUnit'],
#              'plc': ['Language'],
#              'afrique airlines': ['Airline'],
#              'root': ['AnatomicalStructure'],
#              'big': ['FictionalCharacter'],
#              'birthday': ['MilitaryConflict'],
#              'mount royal university': ['EducationalInstitution'],
#              'calliotropis': ['Animal'],
#              'mit': ['Award'],
#              'kroger babb': ['Film'],
#              'anchor': ['Device'],
#              'oswald watt gold medal': ['Award'],
#              'javelin': ['Weapon'],
#              'grant': ['Beverage'],
#              'parameter': ['Food'],
#              'vesuvius national park': ['ProtectedArea'],
#              'annasaheb magar pcmc stadium': ['Venue'],
#              'counterion': ['ChemicalCompound'],
#              'li jinai': ['MilitaryPerson'],
#              'rock island independents': ['SportsTeam'],
#              'northland skink': ['Reptile'],
#              'alexandra panova': ['Athlete'],
#              'compound': ['ChemicalCompound'],
#              'tanith lee': ['Writer'],
#              'pomelo': ['Species'],
#              'experian': ['Company'],
#              'tatenda taibu': ['Cricketer'],
#              'suffrage': ['River'],
#              'arrow': ['Weapon'],
#              'anne shirley': ['FictionalCharacter'],
#              'naval weapons industrial reserve plant dallas': ['MilitaryStructure'],
#              'ivan mauger': ['Athlete'],
#              'rule': ['Album'],
#              'oegstgeest': ['Town'],
#              'spiritism': ['MilitaryUnit'],
#              'phommathat': ['Monarch'],
#              'george granville st baron lansdowne': ['OfficeHolder'],
#              'goddess': ['ComicsCharacter'],
#              'seaman': ['Plant'],
#              'palicidae': ['Crustacean'],
#              'celebrity': ['Cricketer'],
#              'paul westphal': ['Athlete'],
#              'egg': ['Ship'],
#              'borehole': ['HistoricPlace'],
#              'nation': ['Country'],
#              'statute': ['Convention'],
#              'sagenidiopsis': ['Fungus'],
#              'woodland': ['ProtectedArea'],
#              'quintet': ['Band'],
#              'average': ['Settlement'],
#              'diver': ['Comic'],
#              'ster zeeuwsche eilanden': ['SportsEvent'],
#              'severn beach': ['Village'],
#              'bob skinner': ['BaseballPlayer'],
#              'billy gibbons': ['Artist'],
#              'saga': ['InformationAppliance'],
#              'ocular rosacea': ['Disease'],
#              'erannis': ['Insect'],
#              'interchange': ['ShoppingMall'],
#              'comarca': ['Settlement'],
#              'propulsion': ['Software'],
#              'legend': ['Book'],
#              'shootout': ['MilitaryConflict'],
#              'air reserve component': ['ProtectedArea'],
#              'levi b frost house': ['HistoricPlace'],
#              'nine years war': ['Event'],
#              'squid': ['Mollusca'],
#              'stol': ['Aircraft'],
#              'khvaf': ['City'],
#              'layla': ['MusicalWork'],
#              'pilkington': ['Company'],
#              'skeleton': ['AnatomicalStructure'],
#              'oreochromis': ['Animal'],
#              'ssr': ['Drug'],
#              'epidermis': ['AnatomicalStructure'],
#              'skin': ['AnatomicalStructure'],
#              'swim': ['RecordLabel'],
#              'badami': ['Town'],
#              'destruction': ['SportsEvent'],
#              'advocacy': ['Sport'],
#              'jimmy': ['ComicsCharacter'],
#              'physicist': ['Person'],
#              'tirana': ['Settlement'],
#              'walter munk': ['Scientist'],
#              'nembrotha': ['Mollusca'],
#              'castle': ['Building'],
#              'rosella': ['Animal'],
#              'flowers': ['Company'],
#              'marwat': ['Insect'],
#              'snail': ['Species'],
#              'circles': ['Play'],
#              'sanna': ['Weapon'],
#              'empties': ['Film'],
#              'die hesselbachs': ['Play'],
#              'horse': ['Species'],
#              'mousa': ['Island'],
#              'putbus': ['Town'],
#              'chris froome': ['Athlete'],
#              'xiangtan': ['City'],
#              'dunwich': ['Village'],
#              'mantis': ['Species'],
#              'christianity': ['EthnicGroup'],
#              'probability': ['Software'],
#              'helix': ['Album'],
#              'who': ['Song'],
#              'link': ['InformationAppliance'],
#              'gheorghe corduneanu': ['Wrestler'],
#              'wedding': ['Award'],
#              'noise': ['Comic'],
#              'gal': ['Protein'],
#              'suburb': ['Place'],
#              'lake menomin': ['Lake'],
#              'vernal utah': ['City'],
#              'saraswati': ['MythologicalFigure'],
#              'lake daisy': ['Lake'],
#              'potamididae': ['Mollusca'],
#              'james nasmyth': ['Scientist'],
#              'bluesanct records': ['RecordLabel'],
#              'michael hardie boys': ['OfficeHolder'],
#              'assassins': ['Film'],
#              'pine': ['Species'],
#              'cosmospora': ['Fungus'],
#              'cynarctoides': ['Mammal'],
#              'engineering': ['Software'],
#              'bohlen': ['Town'],
#              'insect': ['Animal'],
#              'hobby': ['Sport'],
#              'nick riewoldt': ['Athlete'],
#              'boardwalk': ['Road'],
#              'embryonic': ['MusicalWork'],
#              'thrasher': ['Bird'],
#              'robocup': ['SoccerTournament'],
#              'kennewick high school': ['EducationalInstitution'],
#              'senate': ['Legislature'],
#              'melbourne': ['Place'],
#              'hare island': ['Island'],
#              'fellow': ['Person'],
#              'emergence': ['Election'],
#              'graves': ['Play'],
#              'ramya': ['OfficeHolder'],
#              'chapters': ['Company'],
#              'netherlands': ['Place'],
#              'mine': ['Protein'],
#              'esperanto': ['Language'],
#              'univac series': ['TelevisionShow'],
#              'property': ['TelevisionStation'],
#              'toltec mounds archeological state park': ['HistoricPlace'],
#              'zingel': ['Fish'],
#              'australians': ['EthnicGroup'],
#              'tara feser': ['BasketballPlayer'],
#              'shwegu township': ['Town'],
#              'heart': ['AnatomicalStructure'],
#              'mami kawada': ['MusicalArtist'],
#              'star trek': ['SportsTeam'],
#              'dormitory': ['Building'],
#              'sequel': ['Book'],
#              'choc': ['Actor'],
#              'calcio': ['Magazine'],
#              'macherla': ['Town'],
#              'hollywood': ['Place'],
#              'acadians': ['EthnicGroup'],
#              'fruit': ['Building'],
#              'fleet': ['Aircraft'],
#              'torpedo': ['Weapon'],
#              'bhutto': ['EthnicGroup'],
#              'crew': ['Organisation'],
#              'forever': ['Company'],
#              'samo': ['Royalty'],
#              'reddy': ['EthnicGroup'],
#              'orders': ['Surname'],
#              'manual arts high school': ['EducationalInstitution'],
#              'gastrotheca': ['Amphibian'],
#              'hammer': ['Software'],
#              'diary': ['Album'],
#              'treatise': ['Book'],
#              'taken': ['Film'],
#              'casa': ['Aircraft'],
#              'activated': ['Song'],
#              'hair': ['AnatomicalStructure'],
#              'cargo': ['Airline'],
#              'renovation': ['Election'],
#              'soap': ['ChemicalCompound'],
#              'songs': ['Film'],
#              'lionel bertrand': ['MemberOfParliament'],
#              'tin': ['MilitaryUnit'],
#              'rising damp': ['TelevisionShow'],
#              'doug anthony': ['Politician'],
#              'sitcom': ['MusicGenre'],
#              'mid valley school district': ['School'],
#              'saharanpur': ['City'],
#              'angles': ['EthnicGroup'],
#              'taste': ['Fashion'],
#              'kwa language': ['Language'],
#              'excess': ['Film'],
#              'kappa': ['RadioStation'],
#              'sabha': ['Legislature'],
#              'censorship': ['MilitaryConflict'],
#              'mediation': ['MilitaryConflict'],
#              'miniseries': ['Film'],
#              'albatrellus': ['Fungus'],
#              'madeleine lengle': ['Writer'],
#              'malta': ['Place'],
#              'tus airways': ['Airline'],
#              'flag': ['MusicalWork'],
#              'john c stennis': ['OfficeHolder'],
#              'romania': ['Place'],
#              'oslo': ['Place'],
#              'del': ['SportsLeague'],
#              'blue breasted bee eater': ['Bird'],
#              'slovenes': ['EthnicGroup'],
#              'saving': ['Lake'],
#              'cold': ['Disease'],
#              'viswanathan': ['Surname'],
#              'kinetic records': ['RecordLabel'],
#              'sheep': ['Animal'],
#              'toxic': ['Comic'],
#              'rome': ['Place'],
#              'august von kotzebue': ['Writer'],
#              'leland sklar': ['Artist'],
#              'sore throat': ['Disease'],
#              'plaster': ['ChemicalCompound'],
#              'day': ['Organisation'],
#              'pyramid': ['Building'],
#              'ps a': ['Weapon'],
#              'linguistics': ['Book'],
#              'tsfl season': ['SoccerTournament'],
#              'central falls rhode island': ['City'],
#              'oatlands': ['Village'],
#              'copper': ['MilitaryUnit'],
#              'cw anderson': ['Athlete'],
#              'poultry': ['Bird'],
#              'intersky': ['Airline'],
#              'library': ['Book'],
#              'paragliding': ['Sport'],
#              'eagle cap wilderness': ['ProtectedArea'],
#              'bible': ['Book'],
#              'antifungal': ['ChemicalCompound'],
#              'lovech': ['City'],
#              'ale': ['Beverage'],
#              'metiria turei': ['Politician'],
#              'vilseck': ['Town'],
#              'kitchen': ['Building'],
#              'cavan': ['Place'],
#              'nikkan sports film award': ['Award'],
#              'thallium': ['MilitaryUnit'],
#              'emmy award': ['Award'],
#              'corrosion': ['Election'],
#              'haiti': ['Place'],
#              'econometrics': ['Software'],
#              'structure': ['MusicalWork'],
#              'peine': ['Town'],
#              'holy cross crusaders': ['SportsTeam'],
#              'gastroboletus': ['Fungus'],
#              'basu': ['Surname'],
#              'inuit': ['EthnicGroup'],
#              'lloyd': ['Automobile'],
#              'eldest': ['WrittenWork'],
#              'paris maine': ['Town'],
#              'major': ['Plant'],
#              'suspended': ['VideoGame'],
#              'narsingh deonarine': ['Cricketer'],
#              'hummingbird': ['Bird'],
#              'dotidae': ['Animal'],
#              'ape': ['Organisation'],
#              'sculpture': ['Organisation'],
#              'ict': ['InformationAppliance'],
#              'johnson space center': ['GovernmentAgency'],
#              'composer': ['Person'],
#              'jean': ['Language'],
#              'animation': ['Election'],
#              'calamagrostis': ['Species'],
#              'restaurant': ['Company'],
#              'calcium': ['Drug'],
#              'cane': ['Food'],
#              'fern': ['Species'],
#              'healing': ['Election'],
#              'hyles gallii': ['Species'],
#              'tim': ['Device'],
#              'lamiaceae': ['Species'],
#              'primate': ['Mammal'],
#              'birth': ['Band'],
#              's t sambandam': ['Cricketer'],
#              'yoichi numata': ['Actor'],
#              'hasely crawford': ['Single'],
#              'gamex': ['Convention'],
#              'black buttes': ['MountainRange'],
#              'ever': ['TelevisionShow'],
#              'epithet': ['Artist'],
#              'fingerprint': ['Fashion'],
#              'harry f byrd': ['Politician'],
#              'launch': ['Ship'],
#              'dhe': ['RadioStation'],
#              'oliver paipoonge': ['Town'],
#              'orlando street railway': ['PublicTransitSystem'],
#              'mystery': ['TelevisionShow'],
#              'jimmy cliff': ['Person'],
#              'redoubt': ['MilitaryStructure'],
#              'dusk': ['TelevisionStation'],
#              'shop': ['Protein'],
#              'yamaha raptor': ['Sport'],
#              'mortimer': ['Surname'],
#              'taunton': ['Place'],
#              'gribskov': ['ProtectedArea'],
#              'barney wolfe': ['BaseballPlayer'],
#              'ness': ['Drug'],
#              'mayapur': ['City'],
#              'ethiopia': ['Place'],
#              'quick': ['SoccerClub'],
#              'hogan': ['Building'],
#              'puerto chacabuco': ['Town'],
#              'gmina': ['Organisation'],
#              'vallonia': ['Mollusca'],
#              'whistle': ['Comic'],
#              'crash bandicoot video game': ['Software'],
#              'cashew': ['Species'],
#              'nba street': ['VideoGame'],
#              'broker': ['Person'],
#              'move': ['Automobile'],
#              'butlins': ['Company'],
#              'jack dalrymple': ['OfficeHolder'],
#              'canada': ['Place'],
#              'compressed air': ['MilitaryPerson'],
#              'ice cream maker': ['Software'],
#              'cancricepon': ['Crustacean'],
#              'dogfight': ['MilitaryConflict'],
#              'crystal': ['ChemicalCompound'],
#              'analogy': ['Election'],
#              'rna': ['ChemicalCompound'],
#              ...})

# %%
def write_choi_like_dataset(out_dict):
    if out_dict['mention_span'] in E_test:
        with open('./choi-like-datasets/test.json', 'a') as out:
#             output = '{'
#             output += '"y_str": {}, '.format(["\"{}\"".format(x) for x in out_dict['y_str']])
#             output += '"annot_id" : "MTNCI", '
#             output += '"mention_span": "{}, '.format(out_dict['mention_span'])
#             output += '"right_context_token": {}, '.format(["\"{}\"".format(x) for x in out_dict['right_context_token']])
#             output += '"left_context_token": {}'.format(["\"{}\"".format(x) for x in out_dict['left_context_token']])
#             output += '}\n'
            output = json.dumps(out_dict) + '\n'
            out.write(output)

# %%
len(Y_test)
# Out:
# 27669

# %% [raw]
# {"y_str": ['Animal', 'Crustacean', 'Species', 'Eukaryote'], "annot_id" : "MTNCI", "mention_span": "crab, ""right_context_token": ['cancer', 'greek', 'latin', 'cancer', 'fourth', 'astrological', 'sign', 'associated', 'constellation', 'cancer', 'it', 'spans', 'th', 'degree', 'zodiac', 'degrees', 'celestial', 'longitude', 'under', 'tropical', 'zodiac', 'sun', 'transits', 'area', 'average', 'june', 'july', 'sidereal', 'zodiac', 'sun', 'transits', 'area', 'approximately', 'july', 'august', 'the', 'symbol'], "left_context_token: ['based', 'karkinos', 'giant', 'crab', 'harassed', 'heracles', 'fight', 'hydra']"}

# %%
from tqdm import tqdm
import json

with open('./choi-like-datasets/fair_test.json', 'w') as out_test, \
open('./choi-like-datasets/fair_train.json', 'w') as out_train, \
open('./choi-like-datasets/fair_val.json', 'w') as out_val:

    for entity, concept in tqdm(entity_dict.items()):
        for row, indexes in occurrences_of_entities[entity]:
            for index in indexes:
                out_dict = {}

                out_dict["y_str"] = concept
                out_dict["annot_id"] = 'MTNCI'
                out_dict["mention_span"] = entity
                out_dict['right_context_token'] = c.corpus[row][:index]
                out_dict['left_context_token'] = c.corpus[row][index + len(entity.split(' ')):]

                if out_dict['mention_span'] in E_test:
                    output = json.dumps(out_dict) + '\n'
                    out_test.write(output)
                elif out_dict['mention_span'] in E_train:
                    output = json.dumps(out_dict) + '\n'
                    out_train.write(output)
                elif out_dict['mention_span'] in E_val:
                    output = json.dumps(out_dict) + '\n'
                    out_val.write(output)
# Out:
# 100%|██████████| 13760/13760 [05:56<00:00, 38.64it/s]

# %%
len(found_entity_dict.keys())

# %%
save_data_with_pickle('../source_files/pickles/16_3_multilabel_final_tree', pruned_G)

# %%
save_data_with_pickle('./entity_concepts_dict_(multilabel).pkl', entity_concept_dict)

# %%
set(v[0] for v in entity_dict.values())
# Out:
# {'Actor',
#  'AdministrativeRegion',
#  'Aircraft',
#  'Airline',
#  'Amphibian',
#  'AnatomicalStructure',
#  'Animal',
#  'Arachnid',
#  'Architect',
#  'Artist',
#  'ArtistDiscography',
#  'Athlete',
#  'AustralianRulesFootballPlayer',
#  'Award',
#  'Band',
#  'BaseballPlayer',
#  'BasketballPlayer',
#  'Bird',
#  'BodyOfWater',
#  'Book',
#  'Boxer',
#  'Building',
#  'BusCompany',
#  'City',
#  'Cleric',
#  'Colour',
#  'ComicsCharacter',
#  'ComicsCreator',
#  'Cricketer',
#  'Crustacean',
#  'Currency',
#  'Cyclist',
#  'Dam',
#  'Diocese',
#  'Disease',
#  'EducationalInstitution',
#  'Election',
#  'EthnicGroup',
#  'Eukaryote',
#  'Fashion',
#  'FictionalCharacter',
#  'Film',
#  'Fish',
#  'Food',
#  'Fungus',
#  'GivenName',
#  'Gymnast',
#  'HistoricBuilding',
#  'HistoricPlace',
#  'Holiday',
#  'Hospital',
#  'Insect',
#  'Island',
#  'Lake',
#  'Language',
#  'Legislature',
#  'Mammal',
#  'MemberOfParliament',
#  'MilitaryStructure',
#  'MilitaryUnit',
#  'Mollusca',
#  'Monarch',
#  'Mountain',
#  'MountainRange',
#  'Museum',
#  'Musical',
#  'MusicalWork',
#  'Noble',
#  'OfficeHolder',
#  'Organisation',
#  'Park',
#  'Person',
#  'Place',
#  'Planet',
#  'Plant',
#  'Poem',
#  'PoliticalParty',
#  'Politician',
#  'ProtectedArea',
#  'PublicTransitSystem',
#  'Publisher',
#  'RadioStation',
#  'RailwayLine',
#  'RecordLabel',
#  'ReligiousBuilding',
#  'Reptile',
#  'River',
#  'Road',
#  'Royalty',
#  'RugbyPlayer',
#  'Scientist',
#  'Settlement',
#  'Ship',
#  'ShoppingMall',
#  'Single',
#  'SoccerClub',
#  'SoccerManager',
#  'SoccerPlayer',
#  'SoccerTournament',
#  'Software',
#  'Species',
#  'Sport',
#  'SportsEvent',
#  'SportsTeam',
#  'Surname',
#  'Swimmer',
#  'TelevisionShow',
#  'TennisPlayer',
#  'Town',
#  'Train',
#  'University',
#  'VideoGame',
#  'Village',
#  'Weapon',
#  'WineRegion',
#  'WomensTennisAssociationTournament',
#  'Writer',
#  'Year'}

# %%
import torch
a = torch.load('../source_files/embeddings/16_3_nickel.pth')
a
# Out:
# {'conf': {'checkpoint': 'dbpedia.pth',
#   'dset': 'dbpedia/MTNCI_single_label_edgelist.csv',
#   'dim': 10,
#   'manifold': 'poincare',
#   'model': 'distance',
#   'lr': 0.3,
#   'epochs': 300,
#   'batchsize': 10,
#   'negs': 50,
#   'burnin': 20,
#   'dampening': 0.75,
#   'ndproc': 4,
#   'eval_each': 1,
#   'fresh': True,
#   'debug': False,
#   'gpu': -1,
#   'sym': False,
#   'maxnorm': 500000,
#   'sparse': True,
#   'burnin_multiplier': 0.01,
#   'neg_multiplier': 1.0,
#   'quiet': False,
#   'lr_type': 'constant',
#   'train_threads': 2,
#   'margin': 0.1,
#   'eval': 'reconstruction',
#   'epoch_start': 0},
#  'objects': ['NaturalEvent',
#   'Earthquake',
#   'SolarEclipse',
#   'StormSurge',
#   'Province',
#   'HistoricalProvince',
#   'TimePeriod',
#   'CareerStation',
#   'GeologicalPeriod',
#   'HistoricalPeriod',
#   'PeriodOfArtisticStyle',
#   'PrehistoricalPeriod',
#   'ProtohistoricalPeriod',
#   'Year',
#   'YearInSpaceflight',
#   'AnatomicalStructure',
#   'Artery',
#   'BloodVessel',
#   'Bone',
#   'Brain',
#   'Embryology',
#   'Ligament',
#   'Lymph',
#   'Muscle',
#   'Nerve',
#   'Vein',
#   'Territory',
#   'OldTerritory',
#   'Beverage',
#   'Beer',
#   'Vodka',
#   'Wine',
#   'ControlledDesignationOfOriginWine',
#   'Department',
#   'OverseasDepartment',
#   'SportsSeason',
#   'MotorsportSeason',
#   'SportsTeamSeason',
#   'BaseballSeason',
#   'FootballLeagueSeason',
#   'NationalFootballLeagueSeason',
#   'NCAATeamSeason',
#   'SoccerClubSeason',
#   'SoccerLeagueSeason',
#   'FloweringPlant',
#   'Grape',
#   'SportCompetitionResult',
#   'OlympicResult',
#   'SnookerWorldRanking',
#   'Tower',
#   'Lighthouse',
#   'WaterTower',
#   'ReligiousBuilding',
#   'Abbey',
#   'Church',
#   'Monastery',
#   'Mosque',
#   'Shrine',
#   'Synagogue',
#   'Temple',
#   'MotorcycleRider',
#   'MotocycleRacer',
#   'SpeedwayRider',
#   'ClericalAdministrativeRegion',
#   'Deanery',
#   'Diocese',
#   'Parish',
#   'PowerStation',
#   'NuclearPowerStation',
#   'Name',
#   'GivenName',
#   'Surname',
#   'Instrumentalist',
#   'Guitarist',
#   'Company',
#   'Airline',
#   'Bank',
#   'Brewery',
#   'BusCompany',
#   'Caterer',
#   'LawFirm',
#   'Publisher',
#   'RecordLabel',
#   'Winery',
#   'Wrestler',
#   'SumoWrestler',
#   'GridironFootballPlayer',
#   'AmericanFootballPlayer',
#   'CanadianFootballPlayer',
#   'Engine',
#   'AutomobileEngine',
#   'RocketEngine',
#   'GeneLocation',
#   'HumanGeneLocation',
#   'MouseGeneLocation',
#   'TheologicalConcept',
#   'ChristianDoctrine',
#   'Settlement',
#   'City',
#   'CityDistrict',
#   'HistoricalSettlement',
#   'Town',
#   'Village',
#   'Capital',
#   'CapitalOfRegion',
#   'Software',
#   'VideoGame',
#   'RacingDriver',
#   'DTMRacer',
#   'FormulaOneRacer',
#   'NascarDriver',
#   'RallyDriver',
#   'ArchitecturalStructure',
#   'AmusementParkAttraction',
#   'Arena',
#   'Building',
#   'Gate',
#   'Infrastructure',
#   'MilitaryStructure',
#   'Mill',
#   'Pyramid',
#   'SportFacility',
#   'Square',
#   'Tunnel',
#   'Venue',
#   'Zoo',
#   'RollerCoaster',
#   'WaterRide',
#   'Casino',
#   'Castle',
#   'Factory',
#   'HistoricBuilding',
#   'Hospital',
#   'Hotel',
#   'Library',
#   'Museum',
#   'Prison',
#   'Restaurant',
#   'ShoppingMall',
#   'Skyscraper',
#   'Airport',
#   'Dam',
#   'Dike',
#   'LaunchPad',
#   'Lock',
#   'Port',
#   'RestArea',
#   'RouteOfTransportation',
#   'Bridge',
#   'RailwayLine',
#   'RailwayTunnel',
#   'Road',
#   'RoadJunction',
#   'RoadTunnel',
#   'WaterwayTunnel',
#   'Station',
#   'ElectricalSubstation',
#   'FillingStation',
#   'MetroStation',
#   'RailwayStation',
#   'TramStation',
#   'Fort',
#   'Treadmill',
#   'Watermill',
#   'WindMotor',
#   'Windmill',
#   'CricketGround',
#   'GolfCourse',
#   'RaceTrack',
#   'Racecourse',
#   'SkiArea',
#   'SkiResort',
#   'Stadium',
#   'Theatre',
#   'Event',
#   'Competition',
#   'LifeCycleEvent',
#   'SocietalEvent',
#   'Contest',
#   'PersonalEvent',
#   'Birth',
#   'Death',
#   'Divorce',
#   'Marriage',
#   'AcademicConference',
#   'Attack',
#   'Convention',
#   'Election',
#   'FilmFestival',
#   'Meeting',
#   'MilitaryConflict',
#   'MusicFestival',
#   'Rebellion',
#   'SpaceMission',
#   'SportsEvent',
#   'CyclingCompetition',
#   'FootballMatch',
#   'GrandPrix',
#   'InternationalFootballLeagueEvent',
#   'MixedMartialArtsEvent',
#   'NationalFootballLeagueEvent',
#   'Olympics',
#   'OlympicEvent',
#   'Race',
#   'CyclingRace',
#   'HorseRace',
#   'MotorRace',
#   'Tournament',
#   'GolfTournament',
#   'SoccerTournament',
#   'TennisTournament',
#   'WomensTennisAssociationTournament',
#   'WrestlingEvent',
#   'Country',
#   'HistoricalCountry',
#   'OrganisationMember',
#   'SportsTeamMember',
#   'Case',
#   'LegalCase',
#   'SupremeCourtOfTheUnitedStatesCase',
#   'Boxer',
#   'AmateurBoxer',
#   'Island',
#   'Atoll',
#   'NaturalPlace',
#   'Archipelago',
#   'Beach',
#   'BodyOfWater',
#   'Cape',
#   'Cave',
#   'Crater',
#   'Desert',
#   'Forest',
#   'Glacier',
#   'HotSpring',
#   'Mountain',
#   'MountainPass',
#   'MountainRange',
#   'Valley',
#   'Volcano',
#   'Bay',
#   'Lake',
#   'Ocean',
#   'Sea',
#   'Stream',
#   'Canal',
#   'Creek',
#   'River',
#   'LunarCrater',
#   'SportsManager',
#   'SoccerManager',
#   'Coach',
#   'AmericanFootballCoach',
#   'CollegeCoach',
#   'VolleyballCoach',
#   'Writer',
#   'Historian',
#   'MusicComposer',
#   'PlayWright',
#   'Poet',
#   'ScreenWriter',
#   'SongWriter',
#   'Swarm',
#   'Globularswarm',
#   'Openswarm',
#   'TeamSport',
#   'Soccer',
#   'Politician',
#   'Chancellor',
#   'Congressman',
#   'Deputy',
#   'Governor',
#   'Lieutenant',
#   'Mayor',
#   'MemberOfParliament',
#   'President',
#   'PrimeMinister',
#   'Senator',
#   'VicePresident',
#   'VicePrimeMinister',
#   'TelevisionPersonality',
#   'Host',
#   'Device',
#   'Camera',
#   'InformationAppliance',
#   'Instrument',
#   'MobilePhone',
#   'Weapon',
#   'DigitalCamera',
#   'Guitar',
#   'Organ',
#   'Artwork',
#   'Painting',
#   'Sculpture',
#   'VolleyballPlayer',
#   'BeachVolleyballPlayer',
#   'Non-ProfitOrganisation',
#   'RecordOffice',
#   'Cleric',
#   'Cardinal',
#   'ChristianBishop',
#   'ChristianPatriarch',
#   'Pope',
#   'Priest',
#   'Saint',
#   'Vicar',
#   'Region',
#   'AdministrativeRegion',
#   'HistoricalRegion',
#   'NaturalRegion',
#   'GovernmentalAdministrativeRegion',
#   'Arrondissement',
#   'Canton',
#   'District',
#   'HistoricalDistrict',
#   'DistrictWaterBoard',
#   'MicroRegion',
#   'Municipality',
#   'FormerMunicipality',
#   'Prefecture',
#   'Regency',
#   'SubMunicipality',
#   'HistoricalAreaOfAuthority',
#   'Fiefdom',
#   'SnookerPlayer',
#   'SnookerChamp',
#   'PersonFunction',
#   'PoliticalFunction',
#   'Profession',
#   'MusicalArtist',
#   'BackScene',
#   'ClassicalMusicArtist',
#   'MusicDirector',
#   'Singer',
#   'Presenter',
#   'RadioHost',
#   'TelevisionHost',
#   'Database',
#   'BiologicalDatabase',
#   'MusicalWork',
#   'Album',
#   'ArtistDiscography',
#   'ClassicalMusicComposition',
#   'Musical',
#   'NationalAnthem',
#   'Opera',
#   'Single',
#   'Song',
#   'EurovisionSongContestEntry',
#   'MeanOfTransportation',
#   'Aircraft',
#   'Automobile',
#   'Locomotive',
#   'MilitaryVehicle',
#   'Motorcycle',
#   'On-SiteTransportation',
#   'Rocket',
#   'Ship',
#   'SpaceShuttle',
#   'SpaceStation',
#   'Spacecraft',
#   'Train',
#   'TrainCarriage',
#   'Tram',
#   'MilitaryAircraft',
#   'ConveyorSystem',
#   'Escalator',
#   'MovingWalkway',
#   'Annotation',
#   'Reference',
#   'UnitOfWork',
#   'Project',
#   'ResearchProject',
#   'MotorsportRacer',
#   'Gene',
#   'HumanGene',
#   'MouseGene',
#   'Satellite',
#   'ArtificialSatellite',
#   'GovernmentAgency',
#   'GovernmentCabinet',
#   'Horse',
#   'RaceHorse',
#   'PeriodicalLiterature',
#   'AcademicJournal',
#   'Magazine',
#   'Newspaper',
#   'UndergroundJournal',
#   'Plant',
#   'ClubMoss',
#   'Conifer',
#   'CultivatedVariety',
#   'Cycad',
#   'Fern',
#   'Ginkgo',
#   'Gnetophytes',
#   'GreenAlga',
#   'Moss',
#   'Athlete',
#   'ArcherPlayer',
#   'AthleticsPlayer',
#   'AustralianRulesFootballPlayer',
#   'BadmintonPlayer',
#   'BaseballPlayer',
#   'BasketballPlayer',
#   'Bodybuilder',
#   'BullFighter',
#   'Canoeist',
#   'ChessPlayer',
#   'Cricketer',
#   'Cyclist',
#   'DartsPlayer',
#   'Fencer',
#   'GaelicGamesPlayer',
#   'GolfPlayer',
#   'Gymnast',
#   'HandballPlayer',
#   'HighDiver',
#   'HorseRider',
#   'Jockey',
#   'LacrossePlayer',
#   'MartialArtist',
#   'NationalCollegiateAthleticAssociationAthlete',
#   'NetballPlayer',
#   'PokerPlayer',
#   'Rower',
#   'RugbyPlayer',
#   'SoccerPlayer',
#   'SquashPlayer',
#   'Surfer',
#   'Swimmer',
#   'TableTennisPlayer',
#   'TeamMember',
#   'TennisPlayer',
#   'WaterPoloPlayer',
#   'WinterSportPlayer',
#   'Biathlete',
#   'BobsleighAthlete',
#   'CrossCountrySkier',
#   'Curler',
#   'FigureSkater',
#   'IceHockeyPlayer',
#   'NordicCombined',
#   'Skater',
#   'Skijumper',
#   'Skier',
#   'SpeedSkater',
#   'WrittenWork',
#   'Article',
#   'Book',
#   'Comic',
#   'Drama',
#   'Law',
#   'Letter',
#   'MultiVolumePublication',
#   'Play',
#   'Poem',
#   'Quote',
#   'Resume',
#   'StatedResolution',
#   'Treaty',
#   'Novel',
#   'LightNovel',
#   'ComicStrip',
#   'Manga',
#   'Manhua',
#   'Manhwa',
#   'Royalty',
#   'BritishRoyalty',
#   'Baronet',
#   'Family',
#   'NobleFamily',
#   'Sport',
#   'Athletics',
#   'Boxing',
#   'HorseRiding',
#   'BoxingCategory',
#   'BoxingStyle',
#   'Activity',
#   'Game',
#   'Sales',
#   'BoardGame',
#   'CardGame',
#   'Food',
#   'Cheese',
#   'SportsClub',
#   'HockeyClub',
#   'Work',
#   'Cartoon',
#   'CollectionOfValuables',
#   'Document',
#   'Film',
#   'LineOfFashion',
#   'RadioProgram',
#   'TelevisionEpisode',
#   'TelevisionSeason',
#   'TelevisionShow',
#   'Website',
#   'Anime',
#   'HollywoodCartoon',
#   'Archive',
#   'File',
#   'Image',
#   'MovingImage',
#   'StillImage',
#   'Sound',
#   'Language',
#   'ProgrammingLanguage',
#   'Actor',
#   'AdultActor',
#   'VoiceActor',
#   'Group',
#   'Band',
#   'ComedyGroup',
#   'SportsLeague',
#   'AmericanFootballLeague',
#   'AustralianFootballLeague',
#   'AutoRacingLeague',
#   'BaseballLeague',
#   'BasketballLeague',
#   'BowlingLeague',
#   'BoxingLeague',
#   'CanadianFootballLeague',
#   'CricketLeague',
#   'CurlingLeague',
#   'CyclingLeague',
#   'FieldHockeyLeague',
#   'FormulaOneRacing',
#   'GolfLeague',
#   'HandballLeague',
#   'IceHockeyLeague',
#   'InlineHockeyLeague',
#   'LacrosseLeague',
#   'MixedMartialArtsLeague',
#   'MotorcycleRacingLeague',
#   'PaintballLeague',
#   'PoloLeague',
#   'RadioControlledRacingLeague',
#   'RugbyLeague',
#   'SoccerLeague',
#   'SoftballLeague',
#   'SpeedwayLeague',
#   'TennisLeague',
#   'VideogamesLeague',
#   'VolleyballLeague',
#   'Person',
#   'Ambassador',
#   'Archeologist',
#   'Architect',
#   'Aristocrat',
#   'Artist',
#   'Astronaut',
#   'BeautyQueen',
#   'BusinessPerson',
#   'Celebrity',
#   'Chef',
#   'Criminal',
#   'Economist',
#   'Egyptologist',
#   'Engineer',
#   'Farmer',
#   'FictionalCharacter',
#   'HorseTrainer',
#   'Journalist',
#   'Judge',
#   'Lawyer',
#   'Linguist',
#   'MemberResistanceMovement',
#   'MilitaryPerson',
#   'Model',
#   'Monarch',
#   'MovieDirector',
#   'Noble',
#   'OfficeHolder',
#   'Orphan',
#   'Philosopher',
#   'PlayboyPlaymate',
#   'PoliticianSpouse',
#   'Producer',
#   'Psychologist',
#   'Referee',
#   'Religious',
#   'RomanEmperor',
#   'Scientist',
#   'TelevisionDirector',
#   'TheatreDirector',
#   'Comedian',
#   'ComicsCreator',
#   'Dancer',
#   'FashionDesigner',
#   'Humorist',
#   'Painter',
#   'Photographer',
#   'Sculptor',
#   'Murderer',
#   'SerialKiller',
#   'ComicsCharacter',
#   'AnimangaCharacter',
#   'DisneyCharacter',
#   'MythologicalFigure',
#   'NarutoCharacter',
#   'SoapCharacter',
#   'Biologist',
#   'Entomologist',
#   'Medician',
#   'Professor',
#   'ReligiousOrganisation',
#   'ClericalOrder',
#   'Award',
#   'Decoration',
#   'NobelPrize',
#   'CelestialBody',
#   'Asteroid',
#   'Constellation',
#   'Galaxy',
#   'Planet',
#   'Star',
#   'BrownDwarf',
#   'Agent',
#   'Deity',
#   'Employer',
#   'Organisation',
#   'Broadcaster',
#   'BroadcastNetwork',
#   'RadioStation',
#   'TelevisionStation',
#   'EducationalInstitution',
#   'College',
#   'School',
#   'University',
#   'EmployersOrganisation',
#   'GeopoliticalOrganisation',
#   'InternationalOrganisation',
#   'Legislature',
#   'MilitaryUnit',
#   'Parliament',
#   'PoliticalParty',
#   'PublicTransitSystem',
#   'SambaSchool',
#   'SportsTeam',
#   'AmericanFootballTeam',
#   'AustralianFootballTeam',
#   'BaseballTeam',
#   'BasketballTeam',
#   'CanadianFootballTeam',
#   'CricketTeam',
#   'CyclingTeam',
#   'FormulaOneTeam',
#   'HandballTeam',
#   'HockeyTeam',
#   'RugbyClub',
#   'SoccerClub',
#   'NationalSoccerClub',
#   'SpeedwayTeam',
#   'TermOfOffice',
#   'TradeUnion',
#   'Monument',
#   'GraveMonument',
#   'Memorial',
#   'Eukaryote',
#   'Animal',
#   'Fungus',
#   'Amphibian',
#   'Arachnid',
#   'Bird',
#   'Crustacean',
#   'Fish',
#   'Insect',
#   'Mammal',
#   'Cat',
#   'Dog',
#   'Mollusca',
#   'Reptile',
#   'Relationship',
#   'Ratio',
#   'List',
#   'TrackList',
#   'Biomolecule',
#   'Enzyme',
#   'Hormone',
#   'Lipid',
#   'Polysaccharide',
#   'Protein',
#   'Place',
#   'Cemetery',
#   'ConcentrationCamp',
#   'CountrySeat',
#   'Garden',
#   'HistoricPlace',
#   'Mine',
#   'Park',
#   'PopulatedPlace',
#   'ProtectedArea',
#   'SiteOfSpecialScientificInterest',
#   'WineRegion',
#   'WorldHeritageSite',
#   'CoalPit',
#   'Agglomeration',
#   'Community',
#   'Continent',
#   'GatedCommunity',
#   'Intercommunality',
#   'Locality',
#   'State',
#   'Street',
#   'Genre',
#   'ArtisticGenre',
#   'LiteraryGenre',
#   'MovieGenre',
#   'MusicGenre',
#   'ChemicalSubstance',
#   'ChemicalCompound',
#   'ChemicalElement',
#   'Drug',
#   'Mineral',
#   'Species',
#   'Archaea',
#   'Bacteria',
#   'TopicalConcept',
#   'AcademicSubject',
#   'CardinalDirection',
#   'Fashion',
#   'Ideology',
#   'MathematicalConcept',
#   'PhilosophicalConcept',
#   'PoliticalConcept',
#   'ScientificConcept',
#   'Standard',
#   'SystemOfLaw',
#   'Tax',
#   'Taxon',
#   'Type',
#   'DocumentType',
#   'GovernmentType',
#   'Thing',
#   'GrossDomesticProduct',
#   'Area',
#   'ChartsPlacements',
#   'EthnicGroup',
#   'Holiday',
#   'Flag',
#   'Colour',
#   'Population',
#   'PenaltyShootOut',
#   'Media',
#   'Blazon',
#   'Altitude',
#   'Currency',
#   'Statistic',
#   'Diploma',
#   'PublicService',
#   'Disease',
#   'GrossDomesticProductPerCapita',
#   'ElectionDiagram',
#   'Demographics',
#   'Medicine',
#   'Unknown',
#   'Polyhedron',
#   'RouteStop',
#   'Depth',
#   'HumanDevelopmentIndex'],
#  'model': OrderedDict([('lt.weight',
#                tensor([[ 0.1416,  0.4428, -0.2122,  ...,  0.2912,  0.1697,  0.2620],
#                        [ 0.1405,  0.4407, -0.2110,  ...,  0.2900,  0.1692,  0.2600],
#                        [ 0.1416,  0.4427, -0.2121,  ...,  0.2911,  0.1696,  0.2621],
#                        ...,
#                        [-0.1720,  0.1325,  0.1344,  ...,  0.2527,  0.1104, -0.1677],
#                        [-0.2545, -0.0358,  0.2333,  ...,  0.4029,  0.0065, -0.0715],
#                        [-0.1575,  0.2156,  0.1204,  ...,  0.1989,  0.0685, -0.2025]],
#                       dtype=torch.float64))]),
#  'embeddings': tensor([[ 0.1416,  0.4428, -0.2122,  ...,  0.2912,  0.1697,  0.2620],
#          [ 0.1405,  0.4407, -0.2110,  ...,  0.2900,  0.1692,  0.2600],
#          [ 0.1416,  0.4427, -0.2121,  ...,  0.2911,  0.1696,  0.2621],
#          ...,
#          [-0.1720,  0.1325,  0.1344,  ...,  0.2527,  0.1104, -0.1677],
#          [-0.2545, -0.0358,  0.2333,  ...,  0.4029,  0.0065, -0.0715],
#          [-0.1575,  0.2156,  0.1204,  ...,  0.1989,  0.0685, -0.2025]],
#         dtype=torch.float64),
#  'epoch': 209,
#  'model_type': 'distance'}

# %%
from MTNCI import MTNCI

# %%
model = MTNCI(input_d=1024,
                    out_spec = [{'manifold':'euclid', 
                                'dim':[64, 
                                       10]},
                                {'manifold':'poincare', 
                                 'dim':[128, 128, 10]}],
                    dims = [512, 512])

# %%
def get_n_params(model):
    pp=0
    for p in list(model.parameters()):
        nn=1
        for s in list(p.size()):
            nn = nn*s
        pp += nn
    return pp

# %%
get_n_params(model)
# Out:
# 907132

# %%
len(lopez_data)
# Out:
# 107253

# %%
import random
with open('./choi-like-datasets/fair_test.json', 'r') as in_test:
    lines = in_test.readlines()
    lines = random.sample(lines, len(lines))
    
with open('./choi-like-datasets/shuffled_fair_test.json', 'w') as out:
    for l in lines:
        out.write(l)

with open('./choi-like-datasets/fair_train.json', 'r') as in_train:
    lines = in_train.readlines()
    lines = random.sample(lines, len(lines))
with open('./choi-like-datasets/shuffled_fair_train.json', 'w') as out:
    for l in lines:
        out.write(l)

with open('./choi-like-datasets/fair_val.json', 'r') as in_val:
    lines = in_val.readlines()
    lines = random.sample(lines, len(lines))
    
with open('./choi-like-datasets/shuffled_fair_val.json', 'w') as out:
    for l in lines:
        out.write(l)

# %%
# Out:
# --------------------------------------------------------------------------
# TypeError                                Traceback (most recent call last)
# <ipython-input-20-48e10ea5856a> in <module>
#       1 with open('./B.txt', 'a') as out:
# ----> 2     print(out[0])
#
# TypeError: '_io.TextIOWrapper' object is not subscriptable
