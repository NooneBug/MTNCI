# %%
from preprocessing.EntityNameRetriever import EntityNameRetriever
from preprocessing.graph import graph_from_edgelist, remove_void_types
import networkx as nx
from preprocessing.CorpusManager import CorpusManager
import pickle
from preprocessing.utils import save_data_with_pickle, load_data_with_pickle
import time
import random

# List of classes used to test the correctness of the workflow
# PATH in which utility files are stored
# PICKLES_PATH = '../../source_files/pickles/'
PICKLES_PATH = '/datahdd/vmanuel/MTNCI_datasets/source_files/pickles/'

# PATH that refers to the file which let the building of the Ontology Graph
PATH_TO_EDGELIST = '/datahdd/vmanuel/MTNCI_datasets/source_files/pickles/dbpedia_edgelist_no_closure.tsv'
# PATH to the corpus from which information are extracted
CORPUS_PATH = '/datahdd/vmanuel/ELMo/Corpora/shuffled_text_with_words'
LOG = 'MEGAlog_4_3.txt'

FILE_ID = '16_3'

GRAPH_PATH = PICKLES_PATH + FILE_ID + 'graph'
ENTITY_DICT_PATH = PICKLES_PATH + FILE_ID +'entity_dict'
WORD_INDEXES_PATH = PICKLES_PATH + FILE_ID + 'word_indexes'
WORD_OCCURRENCE_INDEX_PATH = PICKLES_PATH + FILE_ID + 'word_occurrence_indexes'
FOUND_ENTITY_DICT_PATH = PICKLES_PATH + FILE_ID + 'found_entity_dict'
FINAL_TREE_PATH = PICKLES_PATH + FILE_ID + 'final_tree'

LENGTH = 100000

avoid_multilabeling = True

# %%
e = EntityNameRetriever()
entity_dict = load_data_with_pickle(ENTITY_DICT_PATH)

# %%
void_types = [t for t, v in entity_dict.items() if v == []]
G = load_data_with_pickle(GRAPH_PATH)
pruned_G = remove_void_types(G, void_types)

# %%
list_of_classes = [n for n in pruned_G.nodes()]

c = CorpusManager()
c.read_corpus(CORPUS_PATH, LENGTH)
c.create_all_entities(entity_dict, concepts=list_of_classes)    
occurrences_of_entities = load_data_with_pickle(WORD_OCCURRENCE_INDEX_PATH)
# Out:
# read input corpus
# 100%|██████████| 100000/100000 [00:04<00:00, 23952.65it/s]
# 283021 words in vocab
# 118 entities
# 0 entity-tokens in vocab

# %%
list_of_classes
# Out:
# ['NaturalEvent',
#  'Earthquake',
#  'SolarEclipse',
#  'StormSurge',
#  'Province',
#  'HistoricalProvince',
#  'TimePeriod',
#  'CareerStation',
#  'GeologicalPeriod',
#  'HistoricalPeriod',
#  'PeriodOfArtisticStyle',
#  'PrehistoricalPeriod',
#  'ProtohistoricalPeriod',
#  'Year',
#  'YearInSpaceflight',
#  'AnatomicalStructure',
#  'Artery',
#  'BloodVessel',
#  'Bone',
#  'Brain',
#  'Embryology',
#  'Ligament',
#  'Lymph',
#  'Muscle',
#  'Nerve',
#  'Vein',
#  'Territory',
#  'OldTerritory',
#  'Beverage',
#  'Beer',
#  'Vodka',
#  'Wine',
#  'ControlledDesignationOfOriginWine',
#  'Department',
#  'OverseasDepartment',
#  'SportsSeason',
#  'MotorsportSeason',
#  'SportsTeamSeason',
#  'BaseballSeason',
#  'FootballLeagueSeason',
#  'NCAATeamSeason',
#  'SoccerClubSeason',
#  'SoccerLeagueSeason',
#  'FloweringPlant',
#  'Grape',
#  'SportCompetitionResult',
#  'OlympicResult',
#  'SnookerWorldRanking',
#  'Tower',
#  'Lighthouse',
#  'WaterTower',
#  'ReligiousBuilding',
#  'Abbey',
#  'Church',
#  'Monastery',
#  'Mosque',
#  'Shrine',
#  'Synagogue',
#  'Temple',
#  'MotorcycleRider',
#  'MotocycleRacer',
#  'SpeedwayRider',
#  'ClericalAdministrativeRegion',
#  'Deanery',
#  'Diocese',
#  'Parish',
#  'PowerStation',
#  'NuclearPowerStation',
#  'Name',
#  'GivenName',
#  'Surname',
#  'Instrumentalist',
#  'Guitarist',
#  'Company',
#  'Airline',
#  'Bank',
#  'Brewery',
#  'BusCompany',
#  'Caterer',
#  'LawFirm',
#  'Publisher',
#  'RecordLabel',
#  'Winery',
#  'Wrestler',
#  'SumoWrestler',
#  'GridironFootballPlayer',
#  'AmericanFootballPlayer',
#  'CanadianFootballPlayer',
#  'Engine',
#  'AutomobileEngine',
#  'RocketEngine',
#  'GeneLocation',
#  'HumanGeneLocation',
#  'MouseGeneLocation',
#  'TheologicalConcept',
#  'ChristianDoctrine',
#  'Settlement',
#  'City',
#  'CityDistrict',
#  'HistoricalSettlement',
#  'Town',
#  'Village',
#  'Capital',
#  'CapitalOfRegion',
#  'Software',
#  'VideoGame',
#  'RacingDriver',
#  'DTMRacer',
#  'FormulaOneRacer',
#  'NascarDriver',
#  'RallyDriver',
#  'ArchitecturalStructure',
#  'AmusementParkAttraction',
#  'Arena',
#  'Building',
#  'Gate',
#  'Infrastructure',
#  'MilitaryStructure',
#  'Mill',
#  'Pyramid',
#  'SportFacility',
#  'Square',
#  'Tunnel',
#  'Venue',
#  'Zoo',
#  'RollerCoaster',
#  'WaterRide',
#  'Casino',
#  'Castle',
#  'Factory',
#  'HistoricBuilding',
#  'Hospital',
#  'Hotel',
#  'Library',
#  'Museum',
#  'Prison',
#  'Restaurant',
#  'ShoppingMall',
#  'Skyscraper',
#  'Airport',
#  'Dam',
#  'Dike',
#  'LaunchPad',
#  'Lock',
#  'Port',
#  'RestArea',
#  'RouteOfTransportation',
#  'Station',
#  'Fort',
#  'Treadmill',
#  'Watermill',
#  'WindMotor',
#  'Windmill',
#  'CricketGround',
#  'GolfCourse',
#  'RaceTrack',
#  'SkiArea',
#  'Stadium',
#  'Theatre',
#  'Event',
#  'Competition',
#  'LifeCycleEvent',
#  'SocietalEvent',
#  'Contest',
#  'PersonalEvent',
#  'AcademicConference',
#  'Attack',
#  'Convention',
#  'Election',
#  'FilmFestival',
#  'Meeting',
#  'MilitaryConflict',
#  'MusicFestival',
#  'Rebellion',
#  'SpaceMission',
#  'SportsEvent',
#  'Country',
#  'HistoricalCountry',
#  'OrganisationMember',
#  'SportsTeamMember',
#  'Case',
#  'LegalCase',
#  'SupremeCourtOfTheUnitedStatesCase',
#  'Boxer',
#  'AmateurBoxer',
#  'Island',
#  'Atoll',
#  'NaturalPlace',
#  'Archipelago',
#  'Beach',
#  'BodyOfWater',
#  'Cape',
#  'Cave',
#  'Crater',
#  'Desert',
#  'Forest',
#  'Glacier',
#  'HotSpring',
#  'Mountain',
#  'MountainPass',
#  'MountainRange',
#  'Valley',
#  'Volcano',
#  'Bay',
#  'Lake',
#  'Ocean',
#  'Sea',
#  'Stream',
#  'LunarCrater',
#  'Canal',
#  'Creek',
#  'River',
#  'SportsManager',
#  'SoccerManager',
#  'Coach',
#  'AmericanFootballCoach',
#  'CollegeCoach',
#  'VolleyballCoach',
#  'Writer',
#  'Historian',
#  'MusicComposer',
#  'PlayWright',
#  'Poet',
#  'ScreenWriter',
#  'SongWriter',
#  'Swarm',
#  'Globularswarm',
#  'Openswarm',
#  'TeamSport',
#  'Soccer',
#  'Politician',
#  'Chancellor',
#  'Congressman',
#  'Deputy',
#  'Governor',
#  'Lieutenant',
#  'Mayor',
#  'MemberOfParliament',
#  'President',
#  'PrimeMinister',
#  'Senator',
#  'VicePresident',
#  'VicePrimeMinister',
#  'TelevisionPersonality',
#  'Host',
#  'Device',
#  'Camera',
#  'InformationAppliance',
#  'Instrument',
#  'MobilePhone',
#  'Weapon',
#  'DigitalCamera',
#  'Guitar',
#  'Organ',
#  'Artwork',
#  'Painting',
#  'Sculpture',
#  'VolleyballPlayer',
#  'BeachVolleyballPlayer',
#  'Non-ProfitOrganisation',
#  'RecordOffice',
#  'Cleric',
#  'Cardinal',
#  'ChristianBishop',
#  'ChristianPatriarch',
#  'Pope',
#  'Priest',
#  'Saint',
#  'Vicar',
#  'Region',
#  'AdministrativeRegion',
#  'HistoricalRegion',
#  'NaturalRegion',
#  'GovernmentalAdministrativeRegion',
#  'HistoricalAreaOfAuthority',
#  'SnookerPlayer',
#  'SnookerChamp',
#  'PersonFunction',
#  'PoliticalFunction',
#  'Profession',
#  'MusicalArtist',
#  'BackScene',
#  'ClassicalMusicArtist',
#  'MusicDirector',
#  'Singer',
#  'Presenter',
#  'RadioHost',
#  'TelevisionHost',
#  'Database',
#  'BiologicalDatabase',
#  'MusicalWork',
#  'Album',
#  'ArtistDiscography',
#  'ClassicalMusicComposition',
#  'Musical',
#  'NationalAnthem',
#  'Opera',
#  'Single',
#  'Song',
#  'EurovisionSongContestEntry',
#  'MeanOfTransportation',
#  'Aircraft',
#  'Automobile',
#  'Locomotive',
#  'MilitaryVehicle',
#  'Motorcycle',
#  'On-SiteTransportation',
#  'Rocket',
#  'Ship',
#  'SpaceShuttle',
#  'SpaceStation',
#  'Spacecraft',
#  'Train',
#  'TrainCarriage',
#  'Tram',
#  'MilitaryAircraft',
#  'ConveyorSystem',
#  'Escalator',
#  'MovingWalkway',
#  'Annotation',
#  'Reference',
#  'UnitOfWork',
#  'Project',
#  'ResearchProject',
#  'MotorsportRacer',
#  'Gene',
#  'HumanGene',
#  'MouseGene',
#  'Satellite',
#  'ArtificialSatellite',
#  'GovernmentAgency',
#  'GovernmentCabinet',
#  'Horse',
#  'RaceHorse',
#  'PeriodicalLiterature',
#  'AcademicJournal',
#  'Magazine',
#  'Newspaper',
#  'UndergroundJournal',
#  'Plant',
#  'ClubMoss',
#  'Conifer',
#  'CultivatedVariety',
#  'Cycad',
#  'Fern',
#  'Ginkgo',
#  'Gnetophytes',
#  'GreenAlga',
#  'Moss',
#  'SkiResort',
#  'Athlete',
#  'ArcherPlayer',
#  'AthleticsPlayer',
#  'AustralianRulesFootballPlayer',
#  'BadmintonPlayer',
#  'BaseballPlayer',
#  'BasketballPlayer',
#  'Bodybuilder',
#  'BullFighter',
#  'Canoeist',
#  'ChessPlayer',
#  'Cricketer',
#  'Cyclist',
#  'DartsPlayer',
#  'Fencer',
#  'GaelicGamesPlayer',
#  'GolfPlayer',
#  'Gymnast',
#  'HandballPlayer',
#  'HighDiver',
#  'HorseRider',
#  'Jockey',
#  'LacrossePlayer',
#  'MartialArtist',
#  'NationalCollegiateAthleticAssociationAthlete',
#  'NetballPlayer',
#  'PokerPlayer',
#  'Rower',
#  'RugbyPlayer',
#  'SoccerPlayer',
#  'SquashPlayer',
#  'Surfer',
#  'Swimmer',
#  'TableTennisPlayer',
#  'TeamMember',
#  'TennisPlayer',
#  'WaterPoloPlayer',
#  'WinterSportPlayer',
#  'Biathlete',
#  'BobsleighAthlete',
#  'CrossCountrySkier',
#  'Curler',
#  'FigureSkater',
#  'IceHockeyPlayer',
#  'NordicCombined',
#  'Skater',
#  'Skijumper',
#  'Skier',
#  'SpeedSkater',
#  'WrittenWork',
#  'Article',
#  'Book',
#  'Comic',
#  'Drama',
#  'Law',
#  'Letter',
#  'MultiVolumePublication',
#  'Play',
#  'Poem',
#  'Quote',
#  'Resume',
#  'StatedResolution',
#  'Treaty',
#  'Novel',
#  'ComicStrip',
#  'Manga',
#  'Manhua',
#  'Manhwa',
#  'Royalty',
#  'BritishRoyalty',
#  'Baronet',
#  'Family',
#  'NobleFamily',
#  'Sport',
#  'Athletics',
#  'Boxing',
#  'HorseRiding',
#  'BoxingCategory',
#  'BoxingStyle',
#  'Activity',
#  'Game',
#  'Sales',
#  'BoardGame',
#  'CardGame',
#  'Olympics',
#  'OlympicEvent',
#  'Food',
#  'Cheese',
#  'SportsClub',
#  'HockeyClub',
#  'Work',
#  'Cartoon',
#  'CollectionOfValuables',
#  'Document',
#  'Film',
#  'LineOfFashion',
#  'RadioProgram',
#  'TelevisionEpisode',
#  'TelevisionSeason',
#  'TelevisionShow',
#  'Website',
#  'Anime',
#  'HollywoodCartoon',
#  'Archive',
#  'File',
#  'Image',
#  'Sound',
#  'CyclingCompetition',
#  'FootballMatch',
#  'GrandPrix',
#  'InternationalFootballLeagueEvent',
#  'MixedMartialArtsEvent',
#  'NationalFootballLeagueEvent',
#  'Race',
#  'Tournament',
#  'WrestlingEvent',
#  'LightNovel',
#  'Language',
#  'ProgrammingLanguage',
#  'Actor',
#  'AdultActor',
#  'VoiceActor',
#  'Group',
#  'Band',
#  'ComedyGroup',
#  'Birth',
#  'Death',
#  'Divorce',
#  'Marriage',
#  'GolfTournament',
#  'SoccerTournament',
#  'TennisTournament',
#  'WomensTennisAssociationTournament',
#  'SportsLeague',
#  'AmericanFootballLeague',
#  'AustralianFootballLeague',
#  'AutoRacingLeague',
#  'BaseballLeague',
#  'BasketballLeague',
#  'BowlingLeague',
#  'BoxingLeague',
#  'CanadianFootballLeague',
#  'CricketLeague',
#  'CurlingLeague',
#  'CyclingLeague',
#  'FieldHockeyLeague',
#  'FormulaOneRacing',
#  'GolfLeague',
#  'HandballLeague',
#  'IceHockeyLeague',
#  'InlineHockeyLeague',
#  'LacrosseLeague',
#  'MixedMartialArtsLeague',
#  'MotorcycleRacingLeague',
#  'PaintballLeague',
#  'PoloLeague',
#  'RadioControlledRacingLeague',
#  'RugbyLeague',
#  'SoccerLeague',
#  'SoftballLeague',
#  'SpeedwayLeague',
#  'TennisLeague',
#  'VideogamesLeague',
#  'VolleyballLeague',
#  'Person',
#  'Ambassador',
#  'Archeologist',
#  'Architect',
#  'Aristocrat',
#  'Artist',
#  'Astronaut',
#  'BeautyQueen',
#  'BusinessPerson',
#  'Celebrity',
#  'Chef',
#  'Criminal',
#  'Economist',
#  'Egyptologist',
#  'Engineer',
#  'Farmer',
#  'FictionalCharacter',
#  'HorseTrainer',
#  'Journalist',
#  'Judge',
#  'Lawyer',
#  'Linguist',
#  'MemberResistanceMovement',
#  'MilitaryPerson',
#  'Model',
#  'Monarch',
#  'MovieDirector',
#  'Noble',
#  'OfficeHolder',
#  'Orphan',
#  'Philosopher',
#  'PlayboyPlaymate',
#  'PoliticianSpouse',
#  'Producer',
#  'Psychologist',
#  'Referee',
#  'Religious',
#  'RomanEmperor',
#  'Scientist',
#  'TelevisionDirector',
#  'TheatreDirector',
#  'Comedian',
#  'ComicsCreator',
#  'Dancer',
#  'FashionDesigner',
#  'Humorist',
#  'Painter',
#  'Photographer',
#  'Sculptor',
#  'Murderer',
#  'ComicsCharacter',
#  'DisneyCharacter',
#  'MythologicalFigure',
#  'NarutoCharacter',
#  'SoapCharacter',
#  'Biologist',
#  'Entomologist',
#  'Medician',
#  'Professor',
#  'Bridge',
#  'RailwayLine',
#  'RailwayTunnel',
#  'Road',
#  'RoadJunction',
#  'RoadTunnel',
#  'WaterwayTunnel',
#  'ElectricalSubstation',
#  'FillingStation',
#  'MetroStation',
#  'RailwayStation',
#  'TramStation',
#  'ReligiousOrganisation',
#  'ClericalOrder',
#  'NationalFootballLeagueSeason',
#  'Award',
#  'Decoration',
#  'NobelPrize',
#  'CelestialBody',
#  'Asteroid',
#  'Constellation',
#  'Galaxy',
#  'Planet',
#  'Star',
#  'BrownDwarf',
#  'Racecourse',
#  'Agent',
#  'Deity',
#  'Employer',
#  'Organisation',
#  'Broadcaster',
#  'EducationalInstitution',
#  'EmployersOrganisation',
#  'GeopoliticalOrganisation',
#  'InternationalOrganisation',
#  'Legislature',
#  'MilitaryUnit',
#  'Parliament',
#  'PoliticalParty',
#  'PublicTransitSystem',
#  'SambaSchool',
#  'SportsTeam',
#  'TermOfOffice',
#  'TradeUnion',
#  'Monument',
#  'GraveMonument',
#  'Memorial',
#  'Arrondissement',
#  'Canton',
#  'District',
#  'DistrictWaterBoard',
#  'MicroRegion',
#  'Municipality',
#  'Prefecture',
#  'Regency',
#  'SubMunicipality',
#  'HistoricalDistrict',
#  'FormerMunicipality',
#  'Eukaryote',
#  'Animal',
#  'Fungus',
#  'Amphibian',
#  'Arachnid',
#  'Bird',
#  'Crustacean',
#  'Fish',
#  'Insect',
#  'Mammal',
#  'Mollusca',
#  'Reptile',
#  'College',
#  'School',
#  'University',
#  'CyclingRace',
#  'HorseRace',
#  'MotorRace',
#  'Relationship',
#  'Ratio',
#  'AmericanFootballTeam',
#  'AustralianFootballTeam',
#  'BaseballTeam',
#  'BasketballTeam',
#  'CanadianFootballTeam',
#  'CricketTeam',
#  'CyclingTeam',
#  'FormulaOneTeam',
#  'HandballTeam',
#  'HockeyTeam',
#  'RugbyClub',
#  'SoccerClub',
#  'SpeedwayTeam',
#  'NationalSoccerClub',
#  'SerialKiller',
#  'Cat',
#  'Dog',
#  'List',
#  'TrackList',
#  'AnimangaCharacter',
#  'Biomolecule',
#  'Enzyme',
#  'Hormone',
#  'Lipid',
#  'Polysaccharide',
#  'Protein',
#  'BroadcastNetwork',
#  'RadioStation',
#  'TelevisionStation',
#  'MovingImage',
#  'StillImage',
#  'Place',
#  'Cemetery',
#  'ConcentrationCamp',
#  'CountrySeat',
#  'Garden',
#  'HistoricPlace',
#  'Mine',
#  'Park',
#  'PopulatedPlace',
#  'ProtectedArea',
#  'SiteOfSpecialScientificInterest',
#  'WineRegion',
#  'WorldHeritageSite',
#  'CoalPit',
#  'Agglomeration',
#  'Community',
#  'Continent',
#  'GatedCommunity',
#  'Intercommunality',
#  'Locality',
#  'State',
#  'Street',
#  'Genre',
#  'ArtisticGenre',
#  'LiteraryGenre',
#  'MovieGenre',
#  'MusicGenre',
#  'ChemicalSubstance',
#  'ChemicalCompound',
#  'ChemicalElement',
#  'Drug',
#  'Mineral',
#  'Species',
#  'Archaea',
#  'Bacteria',
#  'TopicalConcept',
#  'AcademicSubject',
#  'CardinalDirection',
#  'Fashion',
#  'Ideology',
#  'MathematicalConcept',
#  'PhilosophicalConcept',
#  'PoliticalConcept',
#  'ScientificConcept',
#  'Standard',
#  'SystemOfLaw',
#  'Tax',
#  'Taxon',
#  'Type',
#  'DocumentType',
#  'GovernmentType',
#  'Fiefdom',
#  'Thing',
#  'GrossDomesticProduct',
#  'Area',
#  'ChartsPlacements',
#  'EthnicGroup',
#  'Holiday',
#  'Flag',
#  'Colour',
#  'Population',
#  'PenaltyShootOut',
#  'Media',
#  'Blazon',
#  'Altitude',
#  'Currency',
#  'Statistic',
#  'Diploma',
#  'PublicService',
#  'Disease',
#  'GrossDomesticProductPerCapita',
#  'ElectionDiagram',
#  'Demographics',
#  'Medicine',
#  'Unknown',
#  'Polyhedron',
#  'RouteStop',
#  'Depth',
#  'HumanDevelopmentIndex']

# %%
found_entities = set(occurrences_of_entities.keys())
found_entity_dict = {k: set(v).intersection(found_entities) for k,v in entity_dict.items() if set(v).intersection(found_entities)}

# %%
c.word_indexes = load_data_with_pickle(WORD_INDEXES_PATH)

# %%
occurrences_of_entities['aakash']

# %%
found_entity_dict

# %%
c.check_entity_in_row(ENTITY = 'aakash', ROW = 46355, verbose= True)

# %%
from collections import defaultdict

entity_concept_dict =  defaultdict(list)

for concept, entities in found_entity_dict.items():
    for entity in entities:
        entity_concept_dict[entity].append(concept)

# %%
FILTERED_DATASET_PATH = '../source_files/vectors/' + '16_3' + '/' 

E_TRAIN_PATH = FILTERED_DATASET_PATH + 'filtered_entities_train'
E_VAL_PATH = FILTERED_DATASET_PATH + 'filtered_entities_val'
E_TEST_PATH = FILTERED_DATASET_PATH + 'filtered_entities_test'

E_train = load_data_with_pickle(E_TRAIN_PATH)
E_val = load_data_with_pickle(E_VAL_PATH)
E_test = load_data_with_pickle(E_TEST_PATH)

Y_TRAIN_PATH = FILTERED_DATASET_PATH + 'filtered_Y_train'
Y_VAL_PATH = FILTERED_DATASET_PATH + 'filtered_Y_val'
Y_TEST_PATH = FILTERED_DATASET_PATH + 'filtered_Y_test'

Y_train = load_data_with_pickle(Y_TRAIN_PATH)
Y_val = load_data_with_pickle(Y_VAL_PATH)
Y_test = load_data_with_pickle(Y_TEST_PATH)

from collections import defaultdict
entity_dict = defaultdict(list)

for (Y, E) in [(Y_train, E_train), (Y_val, E_val), (Y_test, E_test)]:
    for y, e in zip(Y, E):
        entity_dict[e] = [y]

# %%
entity_dict
# Out:
# defaultdict(list,
#             {'pashtuns': ['EthnicGroup'],
#              'kilometres': ['Aircraft'],
#              'art': ['TelevisionShow'],
#              'history': ['Book'],
#              'family': ['Band'],
#              'philippines': ['Place'],
#              'poem': ['Poem'],
#              'ophichthus fasciatus': ['Fish'],
#              'february': ['Holiday'],
#              'eisenberg thuringia': ['Town'],
#              'perth': ['Place'],
#              'town': ['Settlement'],
#              'meyers': ['Aircraft'],
#              'election': ['Election'],
#              'writer': ['Person'],
#              'census': ['AnatomicalStructure'],
#              'comune': ['Organisation'],
#              'sinocyclocheilus': ['Fish'],
#              'daughter': ['Mammal'],
#              'tributary': ['River'],
#              'press': ['Publisher'],
#              'gretchen peters': ['Artist'],
#              'soleidae': ['Animal'],
#              'pruchnik': ['Town'],
#              'john': ['Single'],
#              'stanton moore': ['Artist'],
#              'island': ['Museum'],
#              'species': ['FictionalCharacter'],
#              'dick cavett': ['Artist'],
#              'road': ['Road'],
#              'simon upton': ['Politician'],
#              'castle': ['Building'],
#              'gerd kanter': ['Athlete'],
#              'massimo trevisan': ['Swimmer'],
#              'december': ['MusicalWork'],
#              'july': ['Holiday'],
#              'fc grenchen': ['SportsTeam'],
#              'january': ['Holiday'],
#              'halecomorphi': ['Fish'],
#              'pinaglabanan shrine': ['Park'],
#              'palace': ['Building'],
#              'festival': ['SportsEvent'],
#              'miramar rangers': ['SoccerClub'],
#              'baft': ['City'],
#              'moth': ['Species'],
#              'september': ['Holiday'],
#              'pariaman': ['City'],
#              'sister': ['Mammal'],
#              'community': ['Organisation'],
#              'sri': ['Food'],
#              'szczucin': ['Town'],
#              'tournament': ['SoccerTournament'],
#              'pierre deligne': ['Scientist'],
#              'sanskrit': ['Language'],
#              'region': ['Settlement'],
#              'months': ['MusicalWork'],
#              'commander': ['Plant'],
#              'dominique': ['Single'],
#              'phrixus': ['FictionalCharacter'],
#              'red': ['Colour'],
#              'brother': ['Mammal'],
#              'raj rewal': ['Architect'],
#              'black': ['Colour'],
#              'politician': ['Person'],
#              'village': ['Settlement'],
#              'lies': ['RecordLabel'],
#              'cargo': ['Airline'],
#              'white': ['Colour'],
#              'genus': ['Plant'],
#              'lajkovac': ['Town'],
#              'fox': ['Species'],
#              'jim creighton': ['BaseballPlayer'],
#              'santo': ['Athlete'],
#              'seychellois creole': ['Language'],
#              'cinetorhynchus': ['Crustacean'],
#              'castilians': ['EthnicGroup'],
#              'roti': ['Food'],
#              'composer': ['Person'],
#              'taichung': ['Place'],
#              'engineering': ['Software'],
#              'machias maine': ['Town'],
#              'thomasomys': ['Species'],
#              'jack': ['Cricketer'],
#              'frog': ['Noble'],
#              'temple': ['Building'],
#              'latin': ['Language'],
#              'ussr': ['Aircraft'],
#              'army': ['MilitaryUnit'],
#              'washington': ['Ship'],
#              'sussex': ['AdministrativeRegion'],
#              'kieron fonotia': ['RugbyPlayer'],
#              'greg harding': ['AustralianRulesFootballPlayer'],
#              'caffrocrambus': ['Insect'],
#              'matthew': ['Single'],
#              'kamma mountains': ['MountainRange'],
#              'lord': ['WineRegion'],
#              'llyn cwellyn': ['BodyOfWater'],
#              'irish pound': ['Currency'],
#              'eudendrium': ['Animal'],
#              'arabic': ['Language'],
#              'leemans': ['Surname'],
#              'voivodeship': ['Place'],
#              'callirhoe': ['Plant'],
#              'arsenal': ['Aircraft'],
#              'rugby': ['VideoGame'],
#              'clarkia': ['Plant'],
#              'land': ['MusicalWork'],
#              'bohemian': ['Person'],
#              'navy': ['Train'],
#              'mactan': ['Island'],
#              'andrew mccutchen': ['Athlete'],
#              'p n elrod': ['Writer'],
#              'century': ['Year'],
#              'bongaigaon': ['City'],
#              'tour': ['WomensTennisAssociationTournament'],
#              'hypericum': ['Species'],
#              'jack sock': ['Athlete'],
#              'beetle': ['Species'],
#              'yellow': ['Colour'],
#              'brown': ['Colour'],
#              'futi corridor': ['RailwayLine'],
#              'sistan': ['Settlement'],
#              'rav': ['Food'],
#              'experiment': ['AnatomicalStructure'],
#              'junction': ['ShoppingMall'],
#              'diastylis': ['Crustacean'],
#              'senate': ['Legislature'],
#              'phatthalung': ['Town'],
#              'diospyros': ['Species'],
#              'sapium': ['Plant'],
#              'allium': ['Plant'],
#              'pempelia': ['Insect'],
#              'khosa': ['EthnicGroup'],
#              'championship': ['SoccerTournament'],
#              'arizona': ['Place'],
#              'jews': ['EthnicGroup'],
#              'gilia': ['Plant'],
#              'president': ['Person'],
#              'jeeves': ['FictionalCharacter'],
#              'germans': ['EthnicGroup'],
#              'niki': ['Aircraft'],
#              'august': ['Holiday'],
#              'caracas metro': ['PublicTransitSystem'],
#              'cancricepon': ['Crustacean'],
#              'cd lugo': ['SportsTeam'],
#              'nabha': ['City'],
#              'wiegand island': ['Island'],
#              'college': ['University'],
#              'emys': ['Reptile'],
#              'acre': ['Organisation'],
#              'denis johnson': ['Writer'],
#              'eucalyptus': ['Species'],
#              'isophrictis': ['Insect'],
#              'vertiginidae': ['Animal'],
#              'rochester': ['Train'],
#              'scorpion': ['Arachnid'],
#              'old': ['Aircraft'],
#              'nicholas teo': ['Artist'],
#              'chemist': ['Person'],
#              'june': ['Holiday'],
#              'hollands diep': ['River'],
#              'winterburn reservoir': ['Lake'],
#              'language': ['Disease'],
#              'chinas': ['EthnicGroup'],
#              'ohio': ['Place'],
#              'utetheisa': ['Insect'],
#              'poet': ['Person'],
#              'april': ['Holiday'],
#              'varattu pallam dam': ['Dam'],
#              'wrestling': ['Sport'],
#              'labrisomid': ['Species'],
#              'cypress hills interprovincial park': ['ProtectedArea'],
#              'drepanidae': ['Species'],
#              'jos': ['City'],
#              'kansas': ['Place'],
#              'theology': ['Book'],
#              'parish': ['Organisation'],
#              'leonding': ['Town'],
#              'homorodul mare river': ['River'],
#              'leptostylus': ['Insect'],
#              'aidis kruopis': ['Cyclist'],
#              'guruvayur': ['Town'],
#              'krai': ['Organisation'],
#              'november': ['Holiday'],
#              'archery': ['Sport'],
#              'monastery': ['Building'],
#              'jimmy': ['ComicsCharacter'],
#              'thailand': ['Place'],
#              'peak': ['Mountain'],
#              'sahneh': ['City'],
#              'snail': ['Species'],
#              'mojarra': ['Species'],
#              'woerden': ['City'],
#              'matthias bachinger': ['Athlete'],
#              'philosophy': ['Book'],
#              'perth wildcats': ['SportsTeam'],
#              'kashiwa': ['City'],
#              'physicist': ['Person'],
#              'guzman': ['Surname'],
#              'las vegas range': ['MountainRange'],
#              'city': ['Settlement'],
#              'fc martigues': ['SportsTeam'],
#              'ushant': ['Island'],
#              'bee': ['Insect'],
#              'epiphyte': ['Plant'],
#              'canada': ['Place'],
#              'dicentra': ['Plant'],
#              'subdistrict': ['Organisation'],
#              'crivitz wisconsin': ['Village'],
#              'david h depatie': ['Film'],
#              'assyriology': ['Book'],
#              'schei': ['EthnicGroup'],
#              'congress': ['OfficeHolder'],
#              'varzaqan': ['City'],
#              'panzer': ['Food'],
#              'tanta': ['City'],
#              'oromo peoples democratic organization': ['PoliticalParty'],
#              'detroit river international wildlife refuge': ['ProtectedArea'],
#              'adler capelli': ['Cyclist'],
#              'aleksandrovich': ['Surname'],
#              'storm': ['Aircraft'],
#              'initiative': ['Software'],
#              'ernst cassirer': ['Person'],
#              'feathered serpent': ['FictionalCharacter'],
#              'hindi': ['Language'],
#              'sphex': ['Insect'],
#              'ukrainian dialects': ['Politician'],
#              'mausoleum': ['Building'],
#              'jerome brailey': ['Artist'],
#              'khum': ['RadioStation'],
#              'kapoor': ['Surname'],
#              'sivasspor': ['SportsTeam'],
#              'oliver mowat': ['Politician'],
#              'gitxsan': ['EthnicGroup'],
#              'carniola': ['Place'],
#              'cormorant': ['Species'],
#              'henna': ['Species'],
#              'aberford': ['Village'],
#              'white sulphur springs montana': ['City'],
#              'daat': ['Food'],
#              'coniochaetales': ['Fungus'],
#              'constantinople': ['City'],
#              'gary allan': ['Artist'],
#              'rourkela': ['City'],
#              'friar': ['Person'],
#              'babol': ['City'],
#              'curry': ['Food'],
#              'adetus': ['Animal'],
#              'mexico': ['Place'],
#              'zaleski state forest': ['ProtectedArea'],
#              'california': ['Place'],
#              'helston': ['Settlement'],
#              'lake carpa': ['Lake'],
#              'devi': ['Food'],
#              'uss george clymer apa': ['Ship'],
#              'eparchy': ['Food'],
#              'schisandra': ['Plant'],
#              'general': ['Food'],
#              'scarabaeidae': ['Species'],
#              'cathedral': ['Building'],
#              'confessional': ['SoccerPlayer'],
#              'arabs': ['EthnicGroup'],
#              'campsite': ['Settlement'],
#              'commune': ['Settlement'],
#              'krum': ['Monarch'],
#              'astronomer': ['Person'],
#              'meeteetse wyoming': ['Town'],
#              'kinloss': ['Village'],
#              'parrot': ['Bird'],
#              'vlaai': ['Food'],
#              'pallid swift': ['Bird'],
#              'sc toronto': ['SportsTeam'],
#              'axel heiberg island': ['Island'],
#              'toni preckwinkle': ['Politician'],
#              'oregon': ['Place'],
#              'films': ['RecordLabel'],
#              'vavuniya': ['Town'],
#              'bolivians': ['EthnicGroup'],
#              'k l saigal': ['Artist'],
#              'barrie trotter': ['AustralianRulesFootballPlayer'],
#              'kherson': ['Place'],
#              'aira': ['Plant'],
#              'casa': ['Aircraft'],
#              'prefecture': ['Diocese'],
#              'neil goldschmidt': ['OfficeHolder'],
#              'claddagh': ['Town'],
#              'poland': ['Place'],
#              'stan': ['GivenName'],
#              'aleppo': ['Place'],
#              'tehran': ['Place'],
#              'euzophera': ['Animal'],
#              'saint': ['Person'],
#              'usa': ['Ship'],
#              'otjiwarongo': ['City'],
#              'burgh': ['Organisation'],
#              'st benet fink': ['HistoricBuilding'],
#              'kikuchi kan prize': ['Award'],
#              'euro': ['Currency'],
#              'faust': ['FictionalCharacter'],
#              'ryler deheart': ['Athlete'],
#              'omri': ['Monarch'],
#              'flower': ['Species'],
#              'moya brennan': ['Artist'],
#              'babu': ['SoccerPlayer'],
#              'palanpur': ['City'],
#              'islam': ['EthnicGroup'],
#              'carlo canna': ['RugbyPlayer'],
#              'antrodia': ['Fungus'],
#              'holarctic': ['Insect'],
#              'keating': ['Musical'],
#              'exhibition': ['TelevisionShow'],
#              'strauss': ['Surname'],
#              'east troy wisconsin': ['Village'],
#              'bakhsh': ['Organisation'],
#              'window': ['AnatomicalStructure'],
#              'studios': ['RecordLabel'],
#              'phenacogaster': ['Fish'],
#              'rio': ['Film'],
#              'cerro colorado mountains': ['MountainRange'],
#              'koine greek': ['Language'],
#              'tokat': ['City'],
#              'treatise': ['Book'],
#              'oblast': ['Organisation'],
#              'oligosoma infrapunctatum': ['Reptile'],
#              'gnorimoschema': ['Species'],
#              'garhwali language': ['Language'],
#              'malayalam': ['Language'],
#              'lake olivia': ['Lake'],
#              'aedui': ['EthnicGroup'],
#              'prussia': ['Place'],
#              'marcelo melo': ['Athlete'],
#              'adrian peterson': ['Athlete'],
#              'karnataka': ['Place'],
#              'cassinia': ['Plant'],
#              'lauwers': ['River'],
#              'miomantis': ['Animal'],
#              'obec': ['Food'],
#              'ziri': ['Town'],
#              'oedo': ['Island'],
#              'leszno': ['Place'],
#              'angika language': ['Language'],
#              'juan bobo': ['ComicsCharacter'],
#              'fc jazz': ['SportsTeam'],
#              'mauritiana': ['Fungus'],
#              'brendan malone': ['BasketballPlayer'],
#              'alcyna': ['Mollusca'],
#              'eupithecia': ['Species'],
#              'hameenlinna': ['City'],
#              'yvelines': ['Place'],
#              'vera menchik': ['Athlete'],
#              'garhwal himalaya': ['MountainRange'],
#              'screenwriter': ['Person'],
#              'journalist': ['Person'],
#              'curator': ['SoccerManager'],
#              'physidae': ['Animal'],
#              'tritoniidae': ['Animal'],
#              'liu huan': ['Artist'],
#              'james labrie': ['Artist'],
#              'purple': ['Colour'],
#              'westhampton massachusetts': ['Town'],
#              'mansion': ['Building'],
#              'unesco': ['Organisation'],
#              'mitridae': ['Species'],
#              'silkeborg': ['City'],
#              'butte': ['Mountain'],
#              'm t vasudevan nair': ['Writer'],
#              'winchester': ['Place'],
#              'ruskin gallery': ['Museum'],
#              'vaishnavism': ['Organisation'],
#              'cheema': ['EthnicGroup'],
#              'rudraksha': ['Plant'],
#              'diplomat': ['Person'],
#              'blenniella': ['Fish'],
#              'alytus': ['City'],
#              'hyesan': ['City'],
#              'eileen myles': ['Writer'],
#              'norman jewson': ['Architect'],
#              'kannada': ['Language'],
#              'queensland': ['Place'],
#              'colloniidae': ['Species'],
#              'novelist': ['Person'],
#              'designer': ['Person'],
#              'civet': ['Species'],
#              'leicester': ['Place'],
#              'violeta parra': ['Artist'],
#              'fc balzers': ['SportsTeam'],
#              'payyanur': ['City'],
#              'tizi ouzou': ['City'],
#              'synodontis nigrita': ['Fish'],
#              'germany': ['Place'],
#              'ordubad': ['City'],
#              'brenthia': ['Insect'],
#              'subgenus': ['Plant'],
#              'metius': ['Scientist'],
#              'bahawalnagar': ['City'],
#              'baker lake nunavut': ['BodyOfWater'],
#              'gecko': ['Reptile'],
#              'bario': ['Village'],
#              'police': ['Organisation'],
#              'sergey betov': ['TennisPlayer'],
#              'gallery': ['Museum'],
#              'lanius': ['Animal'],
#              'katie taylor': ['Athlete'],
#              'fu jen catholic university': ['EducationalInstitution'],
#              'nk sesvete': ['SoccerClub'],
#              'latham': ['Aircraft'],
#              'graboid': ['FictionalCharacter'],
#              'antioch': ['City'],
#              'hylodes': ['Amphibian'],
#              'uss alabama ssbn': ['Ship'],
#              'spain': ['Place'],
#              'erica dittmer': ['Swimmer'],
#              'gymnastics': ['Sport'],
#              'regent': ['Person'],
#              'selatan': ['Food'],
#              'indore': ['Place'],
#              'father': ['Organisation'],
#              'coast aero center': ['Airline'],
#              'oldman': ['Monarch'],
#              'abel tasman national park': ['ProtectedArea'],
#              'matha': ['Organisation'],
#              'huldrych zwingli': ['Person'],
#              'llyn': ['Food'],
#              'peru': ['Place'],
#              'murong chao': ['Royalty'],
#              'prix blumenthal': ['Award'],
#              'lochearnhead': ['Village'],
#              'oglala lakota': ['EthnicGroup'],
#              'robert hayden': ['Writer'],
#              'bas rutten': ['Athlete'],
#              'the walker brothers discography': ['ArtistDiscography'],
#              'aliso viejo california': ['City'],
#              'arnulfo arias': ['Politician'],
#              'tanel kangert': ['Cyclist'],
#              'jonny lang': ['Artist'],
#              'lancelot': ['Person'],
#              'carpaidion': ['Arachnid'],
#              'krishna prasad bhattarai': ['OfficeHolder'],
#              'kananga': ['City'],
#              'spider': ['Animal'],
#              'professor': ['Plant'],
#              'atypus piceus': ['Arachnid'],
#              'nzhelele dam': ['Dam'],
#              'jamey johnson': ['Artist'],
#              'solegnathus': ['Fish'],
#              'hazaribagh': ['City'],
#              'batac': ['City'],
#              'vestfold': ['AdministrativeRegion'],
#              'baltimore': ['Place'],
#              'spencer white': ['AustralianRulesFootballPlayer'],
#              'luanda': ['Place'],
#              'african rock pipit': ['Bird'],
#              'green': ['Colour'],
#              'astronomy': ['Book'],
#              'florida senate': ['Organisation'],
#              'mylochromis': ['Fish'],
#              'jalandhar': ['Place'],
#              'unia leszno': ['SportsTeam'],
#              'lake spaulding dam': ['Dam'],
#              'mai': ['Aircraft'],
#              'lake meridian': ['Lake'],
#              'pithom': ['City'],
#              'aspergillus awamori': ['Fungus'],
#              'kaj gottlob': ['Architect'],
#              'sielecki': ['Surname'],
#              'grey': ['Colour'],
#              'crambidae': ['Species'],
#              'brian selznick': ['Writer'],
#              'pontifical university antonianum': ['EducationalInstitution'],
#              'uncle': ['Person'],
#              'marty riessen': ['Athlete'],
#              'manhattan': ['Place'],
#              'seabird': ['Bird'],
#              'turnip': ['Species'],
#              'heterobasidion': ['Fungus'],
#              'wadi': ['GivenName'],
#              'banana': ['Plant'],
#              'lake delton': ['Lake'],
#              'freshwater snail': ['Mollusca'],
#              'bagdi': ['EthnicGroup'],
#              'apolima': ['Island'],
#              'don': ['Film'],
#              'coka': ['Town'],
#              'salmas': ['City'],
#              'trillium': ['Species'],
#              'duffus': ['Village'],
#              'william c preston': ['Politician'],
#              'tari': ['RadioStation'],
#              'constantijn huygens prize': ['Award'],
#              'laetiporus': ['Species'],
#              'flabellina iodinea': ['Mollusca'],
#              'winery': ['Building'],
#              'fort des basses perches': ['MilitaryStructure'],
#              'ericales': ['Eukaryote'],
#              'arisaema': ['Species'],
#              'phang nga': ['Town'],
#              'philippine air force': ['Organisation'],
#              'rhonda vincent': ['Artist'],
#              'oppland': ['AdministrativeRegion'],
#              'olearia': ['Plant'],
#              'young finnish party': ['PoliticalParty'],
#              'tiger': ['Eukaryote'],
#              'green iguana': ['Species'],
#              'artillery': ['Weapon'],
#              'pandey': ['EthnicGroup'],
#              'clifden': ['Town'],
#              'papiamento': ['Language'],
#              'arrhenophanidae': ['Insect'],
#              'project': ['Software'],
#              'chaparral': ['Bird'],
#              'john dawes': ['RugbyPlayer'],
#              'john berchmans': ['Cleric'],
#              'chicago': ['Place'],
#              'thornton abbey': ['ReligiousBuilding'],
#              'ewha womans university': ['EducationalInstitution'],
#              'idaho': ['Place'],
#              'federal art project': ['TelevisionShow'],
#              'chaac': ['ComicsCharacter'],
#              'priory': ['ReligiousBuilding'],
#              'malha': ['Village'],
#              'granite mountains arizona': ['MountainRange'],
#              'mycteroperca': ['Fish'],
#              'borough': ['Organisation'],
#              'pali': ['Language'],
#              'adolph alexander weinman': ['Artist'],
#              'calvin chen': ['Actor'],
#              'sault ste marie greyhounds': ['SportsTeam'],
#              'altenkirchen': ['Town'],
#              'salamandra': ['Amphibian'],
#              'celastraceae': ['Species'],
#              'education': ['Election'],
#              'papa': ['City'],
#              'guadalajara': ['Place'],
#              'rut castillo': ['Gymnast'],
#              'lake': ['Place'],
#              'farmhouse': ['Building'],
#              'ghidighici reservoir': ['Lake'],
#              'pelotas': ['City'],
#              'barrister': ['Person'],
#              'dermanyssoidea': ['Arachnid'],
#              'cavanagh': ['Surname'],
#              'sept': ['Food'],
#              'vishnu vardhan': ['Athlete'],
#              'athens': ['Place'],
#              'minneapolis': ['Place'],
#              'kalki koechlin': ['Film'],
#              'molly malone': ['Single'],
#              'sangra': ['EthnicGroup'],
#              'mansfield': ['Place'],
#              'ananda mahidol': ['Royalty'],
#              'giovanni micheletto': ['Cyclist'],
#              'science': ['MusicalWork'],
#              'hirstionyssidae': ['Arachnid'],
#              'transit': ['BusCompany'],
#              'cabeza': ['Food'],
#              'tanza': ['RecordLabel'],
#              'lars bak': ['Cyclist'],
#              'yiddish': ['Language'],
#              'sacristy': ['Building'],
#              'glacier': ['Organisation'],
#              'innsbruck': ['Place'],
#              'heris': ['City'],
#              'robert moses state park long island': ['Park'],
#              'pennsylvania': ['Place'],
#              'dinas mawddwy': ['Village'],
#              'undulambia': ['Insect'],
#              'fabaceae': ['Species'],
#              'zingiberaceae': ['Species'],
#              'ericaceae': ['Species'],
#              'business': ['Organisation'],
#              'karl': ['RadioStation'],
#              'esperanto': ['Language'],
#              'lake chilton': ['Lake'],
#              'santa cruz mountains ava': ['WineRegion'],
#              'mansfeld': ['Town'],
#              'latur': ['City'],
#              'sam': ['Language'],
#              'shadehill reservoir': ['Lake'],
#              'lydia lunch': ['Artist'],
#              'trachelipus': ['Crustacean'],
#              'ada colau': ['Politician'],
#              'khammam': ['City'],
#              'pipefish': ['Species'],
#              'wurundjeri': ['EthnicGroup'],
#              'iyer': ['EthnicGroup'],
#              'london': ['Place'],
#              'georges rossignon': ['Boxer'],
#              'snake': ['Reptile'],
#              'in ultimate challenge mma': ['Year'],
#              'temple us records': ['RecordLabel'],
#              'nigerpeton': ['Amphibian'],
#              'islip oxfordshire': ['Village'],
#              'wife': ['Person'],
#              'florida': ['Place'],
#              'ayrshire': ['AdministrativeRegion'],
#              'francisca': ['Weapon'],
#              'landeck': ['Town'],
#              'susa': ['City'],
#              'princess': ['Plant'],
#              'prelate': ['Person'],
#              'kurnool': ['Settlement'],
#              'mamo': ['Bird'],
#              'otto karl berg': ['Scientist'],
#              'bathyteuthoidea': ['Mollusca'],
#              'unit': ['Organisation'],
#              'bauchi': ['City'],
#              'oslo': ['Place'],
#              'kincardineshire': ['AdministrativeRegion'],
#              'wight': ['Food'],
#              'cherry': ['Plant'],
#              'major': ['Plant'],
#              'pinnacle': ['Fashion'],
#              'albatros l': ['Aircraft'],
#              'vlaardingen': ['City'],
#              'platycercinae': ['Species'],
#              'longnose darter': ['Fish'],
#              'hordaland': ['AdministrativeRegion'],
#              'hyphessobrycon': ['Fish'],
#              'los angeles sparks': ['SportsTeam'],
#              'capitol': ['Train'],
#              'garoua': ['City'],
#              'woodland': ['ProtectedArea'],
#              'scalptia': ['Mollusca'],
#              'jacob van rijs': ['Architect'],
#              'coleophoridae': ['Species'],
#              'meioceras': ['Mollusca'],
#              'nalganga dam': ['Dam'],
#              'monument': ['Building'],
#              'brooks': ['SoccerClub'],
#              'vienna': ['Place'],
#              'flammulated owl': ['Bird'],
#              'military': ['MilitaryUnit'],
#              'orconectes': ['Crustacean'],
#              'frenchay': ['Village'],
#              'tachinidae': ['Species'],
#              'india': ['Place'],
#              'bill schuette': ['OfficeHolder'],
#              'steve bauer': ['Cyclist'],
#              'euchlaena serrata': ['Insect'],
#              'ruskin bond': ['Writer'],
#              'georges darboy': ['Cleric'],
#              'emly': ['Village'],
#              'archdeacon': ['Person'],
#              'seminary': ['University'],
#              'kvatakhevi': ['ReligiousBuilding'],
#              'redoubt': ['MilitaryStructure'],
#              'london colney': ['Village'],
#              'jean': ['Language'],
#              'qatruyeh': ['City'],
#              'lusatia': ['Settlement'],
#              'yerevan dialect': ['Language'],
#              'kalhora': ['EthnicGroup'],
#              'artist': ['Person'],
#              'rahul sankrityayan': ['Writer'],
#              'andrea bargnani': ['Athlete'],
#              'ken doll': ['FictionalCharacter'],
#              'utrecht': ['Place'],
#              'comodoro rivadavia': ['City'],
#              'sordariomycetes': ['Species'],
#              'silpakorn university': ['EducationalInstitution'],
#              'bothriechis': ['Reptile'],
#              'steve lacy': ['Artist'],
#              'melichthys': ['Fish'],
#              'leucogaster': ['Fungus'],
#              'tricholoma': ['Fungus'],
#              'roque de garachico': ['Island'],
#              'justus': ['Cleric'],
#              'mazsalaca': ['Town'],
#              'triceratops': ['Reptile'],
#              'anne mccaffrey': ['Writer'],
#              'ap lei chau': ['Island'],
#              'small': ['Language'],
#              'surdulica': ['Town'],
#              'vaidya': ['Food'],
#              'nova': ['Place'],
#              'stol': ['Aircraft'],
#              'metropolis': ['City'],
#              'trophonius': ['FictionalCharacter'],
#              'rice': ['Plant'],
#              'llanelli rfc': ['SportsTeam'],
#              'cambridge': ['Place'],
#              'ossip zadkine': ['Artist'],
#              'chinnor': ['Village'],
#              'sagaponack new york': ['Village'],
#              'willamette university': ['EducationalInstitution'],
#              'lashari': ['Insect'],
#              'ceremony': ['SportsEvent'],
#              'lark': ['Species'],
#              'drachenbronn air base': ['MilitaryStructure'],
#              'mangochi': ['Town'],
#              'carroll baker': ['Film'],
#              'hms oberon': ['Weapon'],
#              'haryana': ['Place'],
#              'kannapolis intimidators': ['SportsTeam'],
#              'venice': ['Place'],
#              'williamson': ['Planet'],
#              'sundsvall regional hospital': ['Hospital'],
#              'stubble quail': ['Bird'],
#              'juneau raptor center': ['Park'],
#              'channa bleheri': ['Fish'],
#              'arborfield': ['Village'],
#              'afrojack': ['Artist'],
#              'playwright': ['Person'],
#              'frith': ['Food'],
#              'balderton': ['Village'],
#              'arroba': ['SoccerPlayer'],
#              'praslin': ['Island'],
#              'polynesia': ['Settlement'],
#              'krishna': ['FictionalCharacter'],
#              'owl': ['Bird'],
#              'buin va miandasht county': ['AdministrativeRegion'],
#              'emil artin': ['Scientist'],
#              'kandu': ['EthnicGroup'],
#              'virginia': ['Place'],
#              'thali': ['Food'],
#              'kalkan': ['Town'],
#              'marthanda varma': ['Royalty'],
#              'magnus norman': ['Athlete'],
#              'astrophytum': ['Plant'],
#              'udea aurora': ['Insect'],
#              'salama': ['City'],
#              'leucosiidae': ['Crustacean'],
#              'castle peak hospital': ['Hospital'],
#              'prostanthera': ['Plant'],
#              'san francisco cable car system': ['PublicTransitSystem'],
#              'sonnet': ['Poem'],
#              'asteroid': ['Planet'],
#              'missionary': ['Person'],
#              'pomponius mela': ['Person'],
#              'evergreen': ['Plant'],
#              'prionurus': ['Fish'],
#              'nucras': ['Reptile'],
#              'baghdad fc': ['SportsTeam'],
#              'mumbai': ['Place'],
#              'guwahati': ['Place'],
#              'alfieri clan': ['EthnicGroup'],
#              'lombok': ['Place'],
#              'campania': ['Place'],
#              'african forest turtle': ['Reptile'],
#              'pero': ['FictionalCharacter'],
#              'goddess': ['ComicsCharacter'],
#              'niassa reserve': ['ProtectedArea'],
#              'jay': ['Species'],
#              'nottinghamshire': ['Place'],
#              'dirk': ['Weapon'],
#              'romeo': ['FictionalCharacter'],
#              'jainism': ['EthnicGroup'],
#              'straightedge': ['Software'],
#              'jiroft': ['City'],
#              'placostylus': ['Mollusca'],
#              'george zweig': ['Scientist'],
#              'uss sagamore ata': ['Ship'],
#              'baji rao ii': ['Monarch'],
#              'mattawa ontario': ['Town'],
#              'ontario': ['Settlement'],
#              'monk': ['Person'],
#              'marshall sahlins': ['Scientist'],
#              'gymnocephalus': ['Fish'],
#              'fridericianum': ['Museum'],
#              'nickajack dam': ['Dam'],
#              'genetic variability': ['Disease'],
#              'sherburne hills': ['MountainRange'],
#              'waldemar young': ['Writer'],
#              'chthonerpeton noctinectes': ['Amphibian'],
#              'primogeniture': ['River'],
#              'independence kentucky': ['City'],
#              'pascagoula river': ['River'],
#              'babai river': ['BodyOfWater'],
#              'mio': ['Food'],
#              'da nang': ['City'],
#              'tremateia': ['Fungus'],
#              'marrakesh': ['Place'],
#              'lawyer': ['Person'],
#              'coluber bholanathi': ['Reptile'],
#              'ropczyce': ['Town'],
#              'acorn': ['Plant'],
#              'hazaras': ['EthnicGroup'],
#              'ranunculus flammula': ['Plant'],
#              'regina capitals': ['SportsTeam'],
#              'eugenio maria de hostos': ['Writer'],
#              'salmagundi club': ['Building'],
#              'friedberg hesse': ['Town'],
#              'samoana': ['Mollusca'],
#              'sculpture': ['Organisation'],
#              'lioplax': ['Mollusca'],
#              'konstantinos tsaldaris': ['Politician'],
#              'lviv': ['Place'],
#              'agni': ['ComicsCharacter'],
#              'davis elkins college': ['EducationalInstitution'],
#              'todd mcclay': ['Politician'],
#              'il redentore': ['Building'],
#              'arash': ['FictionalCharacter'],
#              'historian': ['Person'],
#              'indiana dunes national lakeshore': ['ProtectedArea'],
#              'cossula': ['Insect'],
#              'champlain college': ['EducationalInstitution'],
#              'danny morton': ['AustralianRulesFootballPlayer'],
#              'baronet': ['Person'],
#              'archbishop': ['Person'],
#              'grand etang lake': ['Lake'],
#              'library': ['Book'],
#              'gleb svyatoslavich': ['Royalty'],
#              'kettle generating station': ['Dam'],
#              'gregory cameron': ['Cleric'],
#              'insurance': ['Software'],
#              'clifford rose': ['Actor'],
#              'sun ma sze tsang': ['Actor'],
#              'meols': ['Village'],
#              'fowl': ['Bird'],
#              'helena arkansas': ['AnatomicalStructure'],
#              'patriarchate': ['Building'],
#              'musician': ['Person'],
#              'friedrich naumann': ['Politician'],
#              'mastacembelus': ['Fish'],
#              'academy': ['University'],
#              'binnya ran ii': ['Royalty'],
#              'suontee': ['Lake'],
#              'st ignatius college': ['EducationalInstitution'],
#              'hopi': ['EthnicGroup'],
#              'causeway': ['Road'],
#              'jiangxi': ['Settlement'],
#              'ege university': ['EducationalInstitution'],
#              'pyramid peak california': ['Mountain'],
#              'achene': ['Plant'],
#              'alice barnes': ['Cyclist'],
#              'governorate': ['Organisation'],
#              'sethi': ['Surname'],
#              'fabrizio giovanardi': ['Athlete'],
#              'piz paradisin': ['Mountain'],
#              'enteucha acetosae': ['Animal'],
#              'kajkavian': ['Language'],
#              'pudu': ['Animal'],
#              'catskill mountain railroad': ['PublicTransitSystem'],
#              'telekom baskets bonn': ['SportsTeam'],
#              'racing': ['VideoGame'],
#              'loweswater': ['BodyOfWater'],
#              'chef': ['Person'],
#              'iguana': ['Species'],
#              'goslar': ['Place'],
#              'elegy': ['Poem'],
#              'lawrenceville illinois': ['City'],
#              'brighton': ['Place'],
#              'moorland': ['ProtectedArea'],
#              'aphid': ['Species'],
#              'muzaffarnagar': ['City'],
#              'nymboida river': ['BodyOfWater'],
#              'cardonville airfield': ['MilitaryStructure'],
#              'sei': ['Food'],
#              'durgapur': ['City'],
#              'twin': ['Mammal'],
#              'terence': ['Person'],
#              'lugh': ['FictionalCharacter'],
#              'toftir': ['Village'],
#              'nanjing normal university': ['EducationalInstitution'],
#              'hertz': ['Organisation'],
#              'psara': ['Island'],
#              'mike griffiths': ['RugbyPlayer'],
#              'fir': ['Species'],
#              'elizabeth gaskell': ['Writer'],
#              'shinto': ['EthnicGroup'],
#              'design': ['Organisation'],
#              'switzerland': ['Place'],
#              'eilema': ['Species'],
#              'malvaceae': ['Species'],
#              'beothuk': ['EthnicGroup'],
#              'cortinariaceae': ['Species'],
#              'admiralty': ['Organisation'],
#              'mordellidae': ['Species'],
#              'kas': ['Food'],
#              'javan lapwing': ['Animal'],
#              'billy graziadei': ['Artist'],
#              'miami fc': ['SportsTeam'],
#              'joshi': ['Surname'],
#              'wasatch mountain state park': ['ProtectedArea'],
#              'atelopus': ['Animal'],
#              'shoulder': ['AnatomicalStructure'],
#              'sjenica': ['Town'],
#              'market': ['Island'],
#              'comedian': ['Person'],
#              'samuel garman': ['Scientist'],
#              'rivera': ['City'],
#              'loch ken': ['BodyOfWater'],
#              'helsinki commuter rail': ['PublicTransitSystem'],
#              'alligator': ['Reptile'],
#              'rufous': ['Colour'],
#              'cameroon': ['Place'],
#              'khabarovsk krai': ['Place'],
#              'josiah winslow': ['Politician'],
#              'cumberland': ['AdministrativeRegion'],
#              'allen': ['AnatomicalStructure'],
#              'dinah washington': ['Artist'],
#              'denis paradis': ['Politician'],
#              'mormyrops': ['Fish'],
#              'hunter hayes': ['Artist'],
#              'bore': ['Weapon'],
#              'avery bradley': ['BasketballPlayer'],
#              'tibet': ['Settlement'],
#              'benenden': ['Village'],
#              'agnes etherington art centre': ['Museum'],
#              'mbeya': ['City'],
#              'sarotherodon': ['Fish'],
#              'ariel ortega': ['Athlete'],
#              'montana': ['Place'],
#              'kolm': ['RadioStation'],
#              'gort': ['Town'],
#              'john medley': ['Cleric'],
#              'peninsula': ['MusicalWork'],
#              'company': ['Organisation'],
#              'mattanur': ['Town'],
#              'rigan county': ['AdministrativeRegion'],
#              'kolkata': ['Place'],
#              'howe island': ['Island'],
#              'crailsheim': ['Town'],
#              'kaushik': ['Surname'],
#              'kiltan': ['Island'],
#              'horton general hospital': ['Hospital'],
#              'egerton university': ['EducationalInstitution'],
#              'chamaesphecia empiformis': ['Insect'],
#              'oreolalax multipunctatus': ['Amphibian'],
#              'lanka sama samaja party': ['PoliticalParty'],
#              'peri': ['FictionalCharacter'],
#              'cocos island': ['ProtectedArea'],
#              'culture': ['TelevisionShow'],
#              'raju': ['EthnicGroup'],
#              'werne': ['Town'],
#              'bagalkot': ['City'],
#              'seneschal': ['Person'],
#              'tolentini venice': ['ReligiousBuilding'],
#              'casey dellacqua': ['Athlete'],
#              'mccurdy': ['Surname'],
#              'zed islands': ['Island'],
#              'kupreanof island': ['Island'],
#              'agent': ['FictionalCharacter'],
#              'matthew stevens': ['Athlete'],
#              'albstadt': ['City'],
#              'synagogue': ['Building'],
#              'anaukpetlun': ['Royalty'],
#              'alejandro sanz': ['Artist'],
#              'curtana': ['Weapon'],
#              'banksiamyces': ['Fungus'],
#              'annesley': ['Village'],
#              'ceanothus': ['Species'],
#              'mashhad county': ['Place'],
#              'hallett peak': ['Mountain'],
#              'udon kiri': ['Weapon'],
#              'ensemble': ['Weapon'],
#              'kankan': ['City'],
#              'murex': ['Species'],
#              'beloit college': ['EducationalInstitution'],
#              'buddy': ['Single'],
#              'pisodonophis': ['Animal'],
#              'butterfly': ['Species'],
#              'pinetop perkins': ['Artist'],
#              'hemiculter': ['Fish'],
#              'geologist': ['Person'],
#              'westland': ['Aircraft'],
#              'camron': ['Artist'],
#              'revolution': ['MusicalWork'],
#              'motueka': ['Town'],
#              'taroudant': ['City'],
#              'coconut': ['Species'],
#              'dasa': ['Food'],
#              'dora rangelova': ['TennisPlayer'],
#              'armenians': ['EthnicGroup'],
#              'salamander': ['Band'],
#              'krama': ['Fashion'],
#              'jianou dialect': ['Language'],
#              'frank ellis boynton': ['Scientist'],
#              'kindia': ['City'],
#              'pfc ludogorets razgrad': ['SportsTeam'],
#              'chickadee': ['Species'],
#              'garrett birkhoff': ['Scientist'],
#              'discodorididae': ['Species'],
#              'diastylis laevis': ['Crustacean'],
#              'docimodus': ['Fish'],
#              'hamza': ['RadioStation'],
#              'abul barkat': ['Aircraft'],
#              'idlib': ['City'],
#              'monde': ['Arachnid'],
#              'thalasseus': ['Bird'],
#              'brian augustyn': ['ComicsCreator'],
#              'jerboa': ['Species'],
#              'hector mcneil': ['Boxer'],
#              'gaggenau': ['Town'],
#              'aisne': ['Place'],
#              'saveh': ['City'],
#              'pernik': ['City'],
#              'greece': ['Place'],
#              'grey elaenia': ['Bird'],
#              'thoroughfare': ['Road'],
#              'tobagonian creole': ['Language'],
#              'copelatus': ['Species'],
#              'hymn': ['Single'],
#              'jordan': ['Place'],
#              'chasma': ['AnatomicalStructure'],
#              'yonas': ['Royalty'],
#              'nikki sixx': ['Artist'],
#              'yoder': ['Surname'],
#              'tullus hostilius': ['Royalty'],
#              'ansel': ['FictionalCharacter'],
#              ...})

# %%
def write_choi_like_dataset(out_dict):
    if out_dict['mention_span'] in E_test:
        with open('./choi-like-datasets/test.json', 'a') as out:
#             output = '{'
#             output += '"y_str": {}, '.format(["\"{}\"".format(x) for x in out_dict['y_str']])
#             output += '"annot_id" : "MTNCI", '
#             output += '"mention_span": "{}, '.format(out_dict['mention_span'])
#             output += '"right_context_token": {}, '.format(["\"{}\"".format(x) for x in out_dict['right_context_token']])
#             output += '"left_context_token": {}'.format(["\"{}\"".format(x) for x in out_dict['left_context_token']])
#             output += '}\n'
            output = json.dumps(out_dict) + '\n'
            out.write(output)

# %% [raw]
# {"y_str": ['Animal', 'Crustacean', 'Species', 'Eukaryote'], "annot_id" : "MTNCI", "mention_span": "crab, ""right_context_token": ['cancer', 'greek', 'latin', 'cancer', 'fourth', 'astrological', 'sign', 'associated', 'constellation', 'cancer', 'it', 'spans', 'th', 'degree', 'zodiac', 'degrees', 'celestial', 'longitude', 'under', 'tropical', 'zodiac', 'sun', 'transits', 'area', 'average', 'june', 'july', 'sidereal', 'zodiac', 'sun', 'transits', 'area', 'approximately', 'july', 'august', 'the', 'symbol'], "left_context_token: ['based', 'karkinos', 'giant', 'crab', 'harassed', 'heracles', 'fight', 'hydra']"}

# %%
from tqdm.notebook import tqdm
import json

with open('./choi-like-datasets/single_label_test.json', 'w') as out_test, \
open('./choi-like-datasets/single_label_train.json', 'w') as out_train, \
open('./choi-like-datasets/single_label_val.json', 'w') as out_val:

    for entity, concept in tqdm(entity_dict.items()):
        for row, indexes in occurrences_of_entities[entity]:
            for index in indexes:
                out_dict = {}

                out_dict["y_str"] = concept
                out_dict["annot_id"] = 'MTNCI'
                out_dict["mention_span"] = entity
                out_dict['right_context_token'] = c.corpus[row][:index]
                out_dict['left_context_token'] = c.corpus[row][index + len(entity.split(' ')):]


                if out_dict['mention_span'] in E_test:
                    output = json.dumps(out_dict) + '\n'
                    out_test.write(output)
                elif out_dict['mention_span'] in E_train:
                    output = json.dumps(out_dict) + '\n'
                    out_train.write(output)
                elif out_dict['mention_span'] in E_val:
                    output = json.dumps(out_dict) + '\n'
                    out_val.write(output)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=25350.0), HTML(value='')))

# %%
len(found_entity_dict.keys())

# %%
save_data_with_pickle('../source_files/pickles/16_3_multilabel_final_tree', pruned_G)

# %%
save_data_with_pickle('./entity_concepts_dict_(multilabel).pkl', entity_concept_dict)

# %%
set(v[0] for v in entity_dict.values())
# Out:
# {'Actor',
#  'AdministrativeRegion',
#  'Aircraft',
#  'Airline',
#  'Amphibian',
#  'AnatomicalStructure',
#  'Animal',
#  'Arachnid',
#  'Architect',
#  'Artist',
#  'ArtistDiscography',
#  'Athlete',
#  'AustralianRulesFootballPlayer',
#  'Award',
#  'Band',
#  'BaseballPlayer',
#  'BasketballPlayer',
#  'Bird',
#  'BodyOfWater',
#  'Book',
#  'Boxer',
#  'Building',
#  'BusCompany',
#  'City',
#  'Cleric',
#  'Colour',
#  'ComicsCharacter',
#  'ComicsCreator',
#  'Cricketer',
#  'Crustacean',
#  'Currency',
#  'Cyclist',
#  'Dam',
#  'Diocese',
#  'Disease',
#  'EducationalInstitution',
#  'Election',
#  'EthnicGroup',
#  'Eukaryote',
#  'Fashion',
#  'FictionalCharacter',
#  'Film',
#  'Fish',
#  'Food',
#  'Fungus',
#  'GivenName',
#  'Gymnast',
#  'HistoricBuilding',
#  'HistoricPlace',
#  'Holiday',
#  'Hospital',
#  'Insect',
#  'Island',
#  'Lake',
#  'Language',
#  'Legislature',
#  'Mammal',
#  'MemberOfParliament',
#  'MilitaryStructure',
#  'MilitaryUnit',
#  'Mollusca',
#  'Monarch',
#  'Mountain',
#  'MountainRange',
#  'Museum',
#  'Musical',
#  'MusicalWork',
#  'Noble',
#  'OfficeHolder',
#  'Organisation',
#  'Park',
#  'Person',
#  'Place',
#  'Planet',
#  'Plant',
#  'Poem',
#  'PoliticalParty',
#  'Politician',
#  'ProtectedArea',
#  'PublicTransitSystem',
#  'Publisher',
#  'RadioStation',
#  'RailwayLine',
#  'RecordLabel',
#  'ReligiousBuilding',
#  'Reptile',
#  'River',
#  'Road',
#  'Royalty',
#  'RugbyPlayer',
#  'Scientist',
#  'Settlement',
#  'Ship',
#  'ShoppingMall',
#  'Single',
#  'SoccerClub',
#  'SoccerManager',
#  'SoccerPlayer',
#  'SoccerTournament',
#  'Software',
#  'Species',
#  'Sport',
#  'SportsEvent',
#  'SportsTeam',
#  'Surname',
#  'Swimmer',
#  'TelevisionShow',
#  'TennisPlayer',
#  'Town',
#  'Train',
#  'University',
#  'VideoGame',
#  'Village',
#  'Weapon',
#  'WineRegion',
#  'WomensTennisAssociationTournament',
#  'Writer',
#  'Year'}

# %%
import torch
a = torch.load('../source_files/embeddings/16_3_nickel.pth')
a
# Out:
# {'conf': {'checkpoint': 'dbpedia.pth',
#   'dset': 'dbpedia/MTNCI_single_label_edgelist.csv',
#   'dim': 10,
#   'manifold': 'poincare',
#   'model': 'distance',
#   'lr': 0.3,
#   'epochs': 300,
#   'batchsize': 10,
#   'negs': 50,
#   'burnin': 20,
#   'dampening': 0.75,
#   'ndproc': 4,
#   'eval_each': 1,
#   'fresh': True,
#   'debug': False,
#   'gpu': -1,
#   'sym': False,
#   'maxnorm': 500000,
#   'sparse': True,
#   'burnin_multiplier': 0.01,
#   'neg_multiplier': 1.0,
#   'quiet': False,
#   'lr_type': 'constant',
#   'train_threads': 2,
#   'margin': 0.1,
#   'eval': 'reconstruction',
#   'epoch_start': 0},
#  'objects': ['NaturalEvent',
#   'Earthquake',
#   'SolarEclipse',
#   'StormSurge',
#   'Province',
#   'HistoricalProvince',
#   'TimePeriod',
#   'CareerStation',
#   'GeologicalPeriod',
#   'HistoricalPeriod',
#   'PeriodOfArtisticStyle',
#   'PrehistoricalPeriod',
#   'ProtohistoricalPeriod',
#   'Year',
#   'YearInSpaceflight',
#   'AnatomicalStructure',
#   'Artery',
#   'BloodVessel',
#   'Bone',
#   'Brain',
#   'Embryology',
#   'Ligament',
#   'Lymph',
#   'Muscle',
#   'Nerve',
#   'Vein',
#   'Territory',
#   'OldTerritory',
#   'Beverage',
#   'Beer',
#   'Vodka',
#   'Wine',
#   'ControlledDesignationOfOriginWine',
#   'Department',
#   'OverseasDepartment',
#   'SportsSeason',
#   'MotorsportSeason',
#   'SportsTeamSeason',
#   'BaseballSeason',
#   'FootballLeagueSeason',
#   'NationalFootballLeagueSeason',
#   'NCAATeamSeason',
#   'SoccerClubSeason',
#   'SoccerLeagueSeason',
#   'FloweringPlant',
#   'Grape',
#   'SportCompetitionResult',
#   'OlympicResult',
#   'SnookerWorldRanking',
#   'Tower',
#   'Lighthouse',
#   'WaterTower',
#   'ReligiousBuilding',
#   'Abbey',
#   'Church',
#   'Monastery',
#   'Mosque',
#   'Shrine',
#   'Synagogue',
#   'Temple',
#   'MotorcycleRider',
#   'MotocycleRacer',
#   'SpeedwayRider',
#   'ClericalAdministrativeRegion',
#   'Deanery',
#   'Diocese',
#   'Parish',
#   'PowerStation',
#   'NuclearPowerStation',
#   'Name',
#   'GivenName',
#   'Surname',
#   'Instrumentalist',
#   'Guitarist',
#   'Company',
#   'Airline',
#   'Bank',
#   'Brewery',
#   'BusCompany',
#   'Caterer',
#   'LawFirm',
#   'Publisher',
#   'RecordLabel',
#   'Winery',
#   'Wrestler',
#   'SumoWrestler',
#   'GridironFootballPlayer',
#   'AmericanFootballPlayer',
#   'CanadianFootballPlayer',
#   'Engine',
#   'AutomobileEngine',
#   'RocketEngine',
#   'GeneLocation',
#   'HumanGeneLocation',
#   'MouseGeneLocation',
#   'TheologicalConcept',
#   'ChristianDoctrine',
#   'Settlement',
#   'City',
#   'CityDistrict',
#   'HistoricalSettlement',
#   'Town',
#   'Village',
#   'Capital',
#   'CapitalOfRegion',
#   'Software',
#   'VideoGame',
#   'RacingDriver',
#   'DTMRacer',
#   'FormulaOneRacer',
#   'NascarDriver',
#   'RallyDriver',
#   'ArchitecturalStructure',
#   'AmusementParkAttraction',
#   'Arena',
#   'Building',
#   'Gate',
#   'Infrastructure',
#   'MilitaryStructure',
#   'Mill',
#   'Pyramid',
#   'SportFacility',
#   'Square',
#   'Tunnel',
#   'Venue',
#   'Zoo',
#   'RollerCoaster',
#   'WaterRide',
#   'Casino',
#   'Castle',
#   'Factory',
#   'HistoricBuilding',
#   'Hospital',
#   'Hotel',
#   'Library',
#   'Museum',
#   'Prison',
#   'Restaurant',
#   'ShoppingMall',
#   'Skyscraper',
#   'Airport',
#   'Dam',
#   'Dike',
#   'LaunchPad',
#   'Lock',
#   'Port',
#   'RestArea',
#   'RouteOfTransportation',
#   'Bridge',
#   'RailwayLine',
#   'RailwayTunnel',
#   'Road',
#   'RoadJunction',
#   'RoadTunnel',
#   'WaterwayTunnel',
#   'Station',
#   'ElectricalSubstation',
#   'FillingStation',
#   'MetroStation',
#   'RailwayStation',
#   'TramStation',
#   'Fort',
#   'Treadmill',
#   'Watermill',
#   'WindMotor',
#   'Windmill',
#   'CricketGround',
#   'GolfCourse',
#   'RaceTrack',
#   'Racecourse',
#   'SkiArea',
#   'SkiResort',
#   'Stadium',
#   'Theatre',
#   'Event',
#   'Competition',
#   'LifeCycleEvent',
#   'SocietalEvent',
#   'Contest',
#   'PersonalEvent',
#   'Birth',
#   'Death',
#   'Divorce',
#   'Marriage',
#   'AcademicConference',
#   'Attack',
#   'Convention',
#   'Election',
#   'FilmFestival',
#   'Meeting',
#   'MilitaryConflict',
#   'MusicFestival',
#   'Rebellion',
#   'SpaceMission',
#   'SportsEvent',
#   'CyclingCompetition',
#   'FootballMatch',
#   'GrandPrix',
#   'InternationalFootballLeagueEvent',
#   'MixedMartialArtsEvent',
#   'NationalFootballLeagueEvent',
#   'Olympics',
#   'OlympicEvent',
#   'Race',
#   'CyclingRace',
#   'HorseRace',
#   'MotorRace',
#   'Tournament',
#   'GolfTournament',
#   'SoccerTournament',
#   'TennisTournament',
#   'WomensTennisAssociationTournament',
#   'WrestlingEvent',
#   'Country',
#   'HistoricalCountry',
#   'OrganisationMember',
#   'SportsTeamMember',
#   'Case',
#   'LegalCase',
#   'SupremeCourtOfTheUnitedStatesCase',
#   'Boxer',
#   'AmateurBoxer',
#   'Island',
#   'Atoll',
#   'NaturalPlace',
#   'Archipelago',
#   'Beach',
#   'BodyOfWater',
#   'Cape',
#   'Cave',
#   'Crater',
#   'Desert',
#   'Forest',
#   'Glacier',
#   'HotSpring',
#   'Mountain',
#   'MountainPass',
#   'MountainRange',
#   'Valley',
#   'Volcano',
#   'Bay',
#   'Lake',
#   'Ocean',
#   'Sea',
#   'Stream',
#   'Canal',
#   'Creek',
#   'River',
#   'LunarCrater',
#   'SportsManager',
#   'SoccerManager',
#   'Coach',
#   'AmericanFootballCoach',
#   'CollegeCoach',
#   'VolleyballCoach',
#   'Writer',
#   'Historian',
#   'MusicComposer',
#   'PlayWright',
#   'Poet',
#   'ScreenWriter',
#   'SongWriter',
#   'Swarm',
#   'Globularswarm',
#   'Openswarm',
#   'TeamSport',
#   'Soccer',
#   'Politician',
#   'Chancellor',
#   'Congressman',
#   'Deputy',
#   'Governor',
#   'Lieutenant',
#   'Mayor',
#   'MemberOfParliament',
#   'President',
#   'PrimeMinister',
#   'Senator',
#   'VicePresident',
#   'VicePrimeMinister',
#   'TelevisionPersonality',
#   'Host',
#   'Device',
#   'Camera',
#   'InformationAppliance',
#   'Instrument',
#   'MobilePhone',
#   'Weapon',
#   'DigitalCamera',
#   'Guitar',
#   'Organ',
#   'Artwork',
#   'Painting',
#   'Sculpture',
#   'VolleyballPlayer',
#   'BeachVolleyballPlayer',
#   'Non-ProfitOrganisation',
#   'RecordOffice',
#   'Cleric',
#   'Cardinal',
#   'ChristianBishop',
#   'ChristianPatriarch',
#   'Pope',
#   'Priest',
#   'Saint',
#   'Vicar',
#   'Region',
#   'AdministrativeRegion',
#   'HistoricalRegion',
#   'NaturalRegion',
#   'GovernmentalAdministrativeRegion',
#   'Arrondissement',
#   'Canton',
#   'District',
#   'HistoricalDistrict',
#   'DistrictWaterBoard',
#   'MicroRegion',
#   'Municipality',
#   'FormerMunicipality',
#   'Prefecture',
#   'Regency',
#   'SubMunicipality',
#   'HistoricalAreaOfAuthority',
#   'Fiefdom',
#   'SnookerPlayer',
#   'SnookerChamp',
#   'PersonFunction',
#   'PoliticalFunction',
#   'Profession',
#   'MusicalArtist',
#   'BackScene',
#   'ClassicalMusicArtist',
#   'MusicDirector',
#   'Singer',
#   'Presenter',
#   'RadioHost',
#   'TelevisionHost',
#   'Database',
#   'BiologicalDatabase',
#   'MusicalWork',
#   'Album',
#   'ArtistDiscography',
#   'ClassicalMusicComposition',
#   'Musical',
#   'NationalAnthem',
#   'Opera',
#   'Single',
#   'Song',
#   'EurovisionSongContestEntry',
#   'MeanOfTransportation',
#   'Aircraft',
#   'Automobile',
#   'Locomotive',
#   'MilitaryVehicle',
#   'Motorcycle',
#   'On-SiteTransportation',
#   'Rocket',
#   'Ship',
#   'SpaceShuttle',
#   'SpaceStation',
#   'Spacecraft',
#   'Train',
#   'TrainCarriage',
#   'Tram',
#   'MilitaryAircraft',
#   'ConveyorSystem',
#   'Escalator',
#   'MovingWalkway',
#   'Annotation',
#   'Reference',
#   'UnitOfWork',
#   'Project',
#   'ResearchProject',
#   'MotorsportRacer',
#   'Gene',
#   'HumanGene',
#   'MouseGene',
#   'Satellite',
#   'ArtificialSatellite',
#   'GovernmentAgency',
#   'GovernmentCabinet',
#   'Horse',
#   'RaceHorse',
#   'PeriodicalLiterature',
#   'AcademicJournal',
#   'Magazine',
#   'Newspaper',
#   'UndergroundJournal',
#   'Plant',
#   'ClubMoss',
#   'Conifer',
#   'CultivatedVariety',
#   'Cycad',
#   'Fern',
#   'Ginkgo',
#   'Gnetophytes',
#   'GreenAlga',
#   'Moss',
#   'Athlete',
#   'ArcherPlayer',
#   'AthleticsPlayer',
#   'AustralianRulesFootballPlayer',
#   'BadmintonPlayer',
#   'BaseballPlayer',
#   'BasketballPlayer',
#   'Bodybuilder',
#   'BullFighter',
#   'Canoeist',
#   'ChessPlayer',
#   'Cricketer',
#   'Cyclist',
#   'DartsPlayer',
#   'Fencer',
#   'GaelicGamesPlayer',
#   'GolfPlayer',
#   'Gymnast',
#   'HandballPlayer',
#   'HighDiver',
#   'HorseRider',
#   'Jockey',
#   'LacrossePlayer',
#   'MartialArtist',
#   'NationalCollegiateAthleticAssociationAthlete',
#   'NetballPlayer',
#   'PokerPlayer',
#   'Rower',
#   'RugbyPlayer',
#   'SoccerPlayer',
#   'SquashPlayer',
#   'Surfer',
#   'Swimmer',
#   'TableTennisPlayer',
#   'TeamMember',
#   'TennisPlayer',
#   'WaterPoloPlayer',
#   'WinterSportPlayer',
#   'Biathlete',
#   'BobsleighAthlete',
#   'CrossCountrySkier',
#   'Curler',
#   'FigureSkater',
#   'IceHockeyPlayer',
#   'NordicCombined',
#   'Skater',
#   'Skijumper',
#   'Skier',
#   'SpeedSkater',
#   'WrittenWork',
#   'Article',
#   'Book',
#   'Comic',
#   'Drama',
#   'Law',
#   'Letter',
#   'MultiVolumePublication',
#   'Play',
#   'Poem',
#   'Quote',
#   'Resume',
#   'StatedResolution',
#   'Treaty',
#   'Novel',
#   'LightNovel',
#   'ComicStrip',
#   'Manga',
#   'Manhua',
#   'Manhwa',
#   'Royalty',
#   'BritishRoyalty',
#   'Baronet',
#   'Family',
#   'NobleFamily',
#   'Sport',
#   'Athletics',
#   'Boxing',
#   'HorseRiding',
#   'BoxingCategory',
#   'BoxingStyle',
#   'Activity',
#   'Game',
#   'Sales',
#   'BoardGame',
#   'CardGame',
#   'Food',
#   'Cheese',
#   'SportsClub',
#   'HockeyClub',
#   'Work',
#   'Cartoon',
#   'CollectionOfValuables',
#   'Document',
#   'Film',
#   'LineOfFashion',
#   'RadioProgram',
#   'TelevisionEpisode',
#   'TelevisionSeason',
#   'TelevisionShow',
#   'Website',
#   'Anime',
#   'HollywoodCartoon',
#   'Archive',
#   'File',
#   'Image',
#   'MovingImage',
#   'StillImage',
#   'Sound',
#   'Language',
#   'ProgrammingLanguage',
#   'Actor',
#   'AdultActor',
#   'VoiceActor',
#   'Group',
#   'Band',
#   'ComedyGroup',
#   'SportsLeague',
#   'AmericanFootballLeague',
#   'AustralianFootballLeague',
#   'AutoRacingLeague',
#   'BaseballLeague',
#   'BasketballLeague',
#   'BowlingLeague',
#   'BoxingLeague',
#   'CanadianFootballLeague',
#   'CricketLeague',
#   'CurlingLeague',
#   'CyclingLeague',
#   'FieldHockeyLeague',
#   'FormulaOneRacing',
#   'GolfLeague',
#   'HandballLeague',
#   'IceHockeyLeague',
#   'InlineHockeyLeague',
#   'LacrosseLeague',
#   'MixedMartialArtsLeague',
#   'MotorcycleRacingLeague',
#   'PaintballLeague',
#   'PoloLeague',
#   'RadioControlledRacingLeague',
#   'RugbyLeague',
#   'SoccerLeague',
#   'SoftballLeague',
#   'SpeedwayLeague',
#   'TennisLeague',
#   'VideogamesLeague',
#   'VolleyballLeague',
#   'Person',
#   'Ambassador',
#   'Archeologist',
#   'Architect',
#   'Aristocrat',
#   'Artist',
#   'Astronaut',
#   'BeautyQueen',
#   'BusinessPerson',
#   'Celebrity',
#   'Chef',
#   'Criminal',
#   'Economist',
#   'Egyptologist',
#   'Engineer',
#   'Farmer',
#   'FictionalCharacter',
#   'HorseTrainer',
#   'Journalist',
#   'Judge',
#   'Lawyer',
#   'Linguist',
#   'MemberResistanceMovement',
#   'MilitaryPerson',
#   'Model',
#   'Monarch',
#   'MovieDirector',
#   'Noble',
#   'OfficeHolder',
#   'Orphan',
#   'Philosopher',
#   'PlayboyPlaymate',
#   'PoliticianSpouse',
#   'Producer',
#   'Psychologist',
#   'Referee',
#   'Religious',
#   'RomanEmperor',
#   'Scientist',
#   'TelevisionDirector',
#   'TheatreDirector',
#   'Comedian',
#   'ComicsCreator',
#   'Dancer',
#   'FashionDesigner',
#   'Humorist',
#   'Painter',
#   'Photographer',
#   'Sculptor',
#   'Murderer',
#   'SerialKiller',
#   'ComicsCharacter',
#   'AnimangaCharacter',
#   'DisneyCharacter',
#   'MythologicalFigure',
#   'NarutoCharacter',
#   'SoapCharacter',
#   'Biologist',
#   'Entomologist',
#   'Medician',
#   'Professor',
#   'ReligiousOrganisation',
#   'ClericalOrder',
#   'Award',
#   'Decoration',
#   'NobelPrize',
#   'CelestialBody',
#   'Asteroid',
#   'Constellation',
#   'Galaxy',
#   'Planet',
#   'Star',
#   'BrownDwarf',
#   'Agent',
#   'Deity',
#   'Employer',
#   'Organisation',
#   'Broadcaster',
#   'BroadcastNetwork',
#   'RadioStation',
#   'TelevisionStation',
#   'EducationalInstitution',
#   'College',
#   'School',
#   'University',
#   'EmployersOrganisation',
#   'GeopoliticalOrganisation',
#   'InternationalOrganisation',
#   'Legislature',
#   'MilitaryUnit',
#   'Parliament',
#   'PoliticalParty',
#   'PublicTransitSystem',
#   'SambaSchool',
#   'SportsTeam',
#   'AmericanFootballTeam',
#   'AustralianFootballTeam',
#   'BaseballTeam',
#   'BasketballTeam',
#   'CanadianFootballTeam',
#   'CricketTeam',
#   'CyclingTeam',
#   'FormulaOneTeam',
#   'HandballTeam',
#   'HockeyTeam',
#   'RugbyClub',
#   'SoccerClub',
#   'NationalSoccerClub',
#   'SpeedwayTeam',
#   'TermOfOffice',
#   'TradeUnion',
#   'Monument',
#   'GraveMonument',
#   'Memorial',
#   'Eukaryote',
#   'Animal',
#   'Fungus',
#   'Amphibian',
#   'Arachnid',
#   'Bird',
#   'Crustacean',
#   'Fish',
#   'Insect',
#   'Mammal',
#   'Cat',
#   'Dog',
#   'Mollusca',
#   'Reptile',
#   'Relationship',
#   'Ratio',
#   'List',
#   'TrackList',
#   'Biomolecule',
#   'Enzyme',
#   'Hormone',
#   'Lipid',
#   'Polysaccharide',
#   'Protein',
#   'Place',
#   'Cemetery',
#   'ConcentrationCamp',
#   'CountrySeat',
#   'Garden',
#   'HistoricPlace',
#   'Mine',
#   'Park',
#   'PopulatedPlace',
#   'ProtectedArea',
#   'SiteOfSpecialScientificInterest',
#   'WineRegion',
#   'WorldHeritageSite',
#   'CoalPit',
#   'Agglomeration',
#   'Community',
#   'Continent',
#   'GatedCommunity',
#   'Intercommunality',
#   'Locality',
#   'State',
#   'Street',
#   'Genre',
#   'ArtisticGenre',
#   'LiteraryGenre',
#   'MovieGenre',
#   'MusicGenre',
#   'ChemicalSubstance',
#   'ChemicalCompound',
#   'ChemicalElement',
#   'Drug',
#   'Mineral',
#   'Species',
#   'Archaea',
#   'Bacteria',
#   'TopicalConcept',
#   'AcademicSubject',
#   'CardinalDirection',
#   'Fashion',
#   'Ideology',
#   'MathematicalConcept',
#   'PhilosophicalConcept',
#   'PoliticalConcept',
#   'ScientificConcept',
#   'Standard',
#   'SystemOfLaw',
#   'Tax',
#   'Taxon',
#   'Type',
#   'DocumentType',
#   'GovernmentType',
#   'Thing',
#   'GrossDomesticProduct',
#   'Area',
#   'ChartsPlacements',
#   'EthnicGroup',
#   'Holiday',
#   'Flag',
#   'Colour',
#   'Population',
#   'PenaltyShootOut',
#   'Media',
#   'Blazon',
#   'Altitude',
#   'Currency',
#   'Statistic',
#   'Diploma',
#   'PublicService',
#   'Disease',
#   'GrossDomesticProductPerCapita',
#   'ElectionDiagram',
#   'Demographics',
#   'Medicine',
#   'Unknown',
#   'Polyhedron',
#   'RouteStop',
#   'Depth',
#   'HumanDevelopmentIndex'],
#  'model': OrderedDict([('lt.weight',
#                tensor([[ 0.1416,  0.4428, -0.2122,  ...,  0.2912,  0.1697,  0.2620],
#                        [ 0.1405,  0.4407, -0.2110,  ...,  0.2900,  0.1692,  0.2600],
#                        [ 0.1416,  0.4427, -0.2121,  ...,  0.2911,  0.1696,  0.2621],
#                        ...,
#                        [-0.1720,  0.1325,  0.1344,  ...,  0.2527,  0.1104, -0.1677],
#                        [-0.2545, -0.0358,  0.2333,  ...,  0.4029,  0.0065, -0.0715],
#                        [-0.1575,  0.2156,  0.1204,  ...,  0.1989,  0.0685, -0.2025]],
#                       dtype=torch.float64))]),
#  'embeddings': tensor([[ 0.1416,  0.4428, -0.2122,  ...,  0.2912,  0.1697,  0.2620],
#          [ 0.1405,  0.4407, -0.2110,  ...,  0.2900,  0.1692,  0.2600],
#          [ 0.1416,  0.4427, -0.2121,  ...,  0.2911,  0.1696,  0.2621],
#          ...,
#          [-0.1720,  0.1325,  0.1344,  ...,  0.2527,  0.1104, -0.1677],
#          [-0.2545, -0.0358,  0.2333,  ...,  0.4029,  0.0065, -0.0715],
#          [-0.1575,  0.2156,  0.1204,  ...,  0.1989,  0.0685, -0.2025]],
#         dtype=torch.float64),
#  'epoch': 209,
#  'model_type': 'distance'}

# %%
from MTNCI import MTNCI

# %%
model = MTNCI(input_d=1024,
                    out_spec = [{'manifold':'euclid', 
                                'dim':[64, 
                                       10]},
                                {'manifold':'poincare', 
                                 'dim':[128, 128, 10]}],
                    dims = [512, 512])

# %%
def get_n_params(model):
    pp=0
    for p in list(model.parameters()):
        nn=1
        for s in list(p.size()):
            nn = nn*s
        pp += nn
    return pp

# %%
get_n_params(model)
# Out:
# 907132

# %%
len(lopez_data)
# Out:
# 107253
